# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Привет еще раз. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <b>Комментарий от ревьюера</b>
#
# Привет! Меня зовут Ярослав Кальманов, я буду делать ревью твоего проекта. Давай будем общаться на «ты».
#
# Мои комментарии будут в ячейках "Комментарий от ревьюера".
#
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера ❗</b>
#
# Красным цветом обозначены комментарии, на которые тебе нужно обратить внимание в первую очередь, чтобы я принял проект.
# </div>
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера ⚠️</b>
#
# Желтым цветом отмечено то, что ты можешь сделать немного по-другому. Ты можешь учесть эти комментарии при выполнении следующих проектов.
# </div>
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Зелёным цветом обозначены твои удачные решения, которые ты без сомнения можешь применять в будущих проектах.
# </div>
#
# Если ты вносишь изменения в проект по моим рекомендациям, указывай, пожалуйста, это в своих комментариях. Будет удобно, если обозначишь свои комментарии заметным цветом или поместишь
#
# <div class="alert alert-info">
#
# в такую ячейку
# </div>
#
# Давай при работе с проектом мы будем общаться с тобой в диалоге, поэтому не удаляй и не перемещай мои комментарии, это поможет мне сделать повторную  проверку проекта быстрее.
# ___

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Ярослав, привет! Все поняла. Вносимые в проект изменения буду сопровождатьсвоими комментариями.
# </div>

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# Исследование данных о российском конопроката проводится по заказу Министерства культуры Российской Федерации с целью изучить рынок российского кинопроката и выявлению текущих трендов.
#
# К исследованию представлены данные, опубликованные на портале открытых данных Министерства культуры, а также информация с сайта КиноПоиск.
#
# **Описание данных**
#
# Таблица mkrf_movies содержит информацию из реестра прокатных удостоверений.
#
# **-title**
# *- название фильма;*
#
# **-puNumber**
# *- номер прокатного удостоверения;*
#
# **-show_start_date**
# *-дата премьеры фильма;*
#
# **-type**
# *- тип фильма;*
#
# **-film_studio**
# *- студия-производитель;*
#
# **-production_country**
# *-страна-производитель;*
#
# **-director**
# *- режиссёр;*
#
# **-producer**
# *- продюсер;*
#
# **-age_restriction**
# *- возрастная категория;*
#
# **-refundable_support**
# *- объём возвратных средств государственной поддержки;*
#
# **-nonrefundable_support**
# *- объём невозвратных средств государственной поддержки;*
#
# **-financing_source**
# *- источник государственного финансирования;*
#
# **-budget**
# *- общий бюджет фильма;*
#
# **-ratings**
# *- рейтинг фильма на КиноПоиске;*
#
# **-genres**
# *- жанр фильма.*
#
# Таблица mkrf_shows содержит сведения о показах фильмов в российских кинотеатрах.
#
# **-puNumber**
# *- номер прокатного удостоверения;*
#
# **-box_office**
# *- сборы в рублях.*

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера</b>
#
# В начале работы стоит добавить описание проекта, чтобы твои коллеги понимали цели исследования. Это поможет и тебе, если ты вернешься к проекту спустя время.
#
# Еще сюда можно добавить описание данных и оглавление. Описание поможет быстрее разобраться, что у нас лежит в датафрейме, а оглавление позволит понять охваченные вопросы и поможет сразу перейти к нужному разделу.
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Добавила описание проекта и описание данных. Работаю в окружении Практикума, оглавление здесь есть. Для будущих работ возьму на заметку.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# 👍
# </div>

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
import pandas as pd
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets
iris = datasets.load_iris()
import seaborn as sns
import re

# %% [markdown]
# Загружаем и открываем файлы с данными.

# %%
pd.options.display.float_format = '{:,.2f}'.format
data_1=pd.read_csv('/datasets/mkrf_movies.csv')
data_2=pd.read_csv('/datasets/mkrf_shows.csv')

# %%
data_1.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres
# 0     NaN              NaN     7.2     боевик,драма,мелодрама
# 1     NaN              NaN     6.6              драма,военный
# 2     NaN              NaN     6.8  фантастика,боевик,триллер
# 3     NaN              NaN     6.8  фантастика,боевик,триллер
# 4     NaN              NaN     6.8  фантастика,боевик,триллер

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB

# %%
data_2.head()
# Out:
#     puNumber     box_office
# 0  111000113       2,450.00
# 1  111000115      61,040.00
# 2  111000116 153,030,013.40
# 3  111000117  12,260,956.00
# 4  111000118 163,684,057.79

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# Изменим тип данных в столбце puNumber с int64 на str, чтобы при объединении объектов данные столбца, по которому идет объединение, были одного типа.

# %%
data_2['puNumber']=data_2['puNumber'].astype('str')
data_2['puNumber']
# Out:
# 0       111000113
# 1       111000115
# 2       111000116
# 3       111000117
# 4       111000118
#           ...
# 3153    224014814
# 3154    224021411
# 3155    224022410
# 3156    224023210
# 3157    224026410
# Name: puNumber, Length: 3158, dtype: object

# %% [markdown]
# Объединяем данные в один датафрейм.

# %%
data=data_1.merge(data_2, on='puNumber', how='left')
data.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %% [markdown]
# Выведем названия столбцов датафрейма, приведем их к одному виду.

# %%
data.columns
# Out:
# Index(['title', 'puNumber', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %%
data=data.rename(columns={'puNumber':'pu_number','nonrefundable_support':'non_refundable_support'})

# %%
data.columns
# Out:
# Index(['title', 'pu_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'non_refundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %% [markdown]
# Переименованы 2 столбца -'puNumber' в 'pu_number' и 'nonrefundable_support' в 'non_refundable_support'.

# %%
data.hist(figsize=(10,10));

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# > array([[<AxesSubplot:title={'center':'refundable_support'}>,
#
# Можно добавить в конце `;` или `plt.show()`, чтобы убрать эти служебные строки
#
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Спасибо! Служебные строки убрала.
# </div>

# %%
data.describe()
# Out:
#        refundable_support  non_refundable_support           budget  \
# count              332.00                  332.00           332.00
# mean        11,864,457.83           48,980,988.89   127,229,716.68
# std         24,916,555.26           59,980,117.92   188,588,333.12
# min                  0.00                    0.00             0.00
# 25%                  0.00           25,000,000.00    42,000,000.00
# 50%                  0.00           30,000,000.00    68,649,916.00
# 75%         15,000,000.00           40,375,000.00   141,985,319.50
# max        180,000,000.00          400,000,000.00 2,305,074,303.00
#
#             box_office
# count         3,158.00
# mean     76,478,696.16
# std     240,353,122.82
# min               0.00
# 25%          86,239.00
# 50%       2,327,987.55
# 75%      23,979,671.02
# max   3,073,568,690.79

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Из-за того, что числа большие, они записываются в экспоненциальной форме. Можно изменить формат чисел в проекте на привычный, если добавить в начале файла строку
#
# `pd.options.display.float_format = '{:,.2f}'.format`
#
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Спасибо! Так гораздо лучше!
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# 👍
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   7486 non-null   object
#  1   pu_number               7486 non-null   object
#  2   show_start_date         7486 non-null   object
#  3   type                    7486 non-null   object
#  4   film_studio             7468 non-null   object
#  5   production_country      7484 non-null   object
#  6   director                7477 non-null   object
#  7   producer                6918 non-null   object
#  8   age_restriction         7486 non-null   object
#  9   refundable_support      332 non-null    float64
#  10  non_refundable_support  332 non-null    float64
#  11  budget                  332 non-null    float64
#  12  financing_source        332 non-null    object
#  13  ratings                 6519 non-null   object
#  14  genres                  6510 non-null   object
#  15  box_office              3158 non-null   float64
# dtypes: float64(4), object(12)
# memory usage: 994.2+ KB

# %% [markdown]
#  **Вывод:**
#
# ***Всего файл содержит 7486 записей по объектам рынка российского кинопроката, 16 столбцов признаков (4 количественных, 11 категориальных и 1 временной). Для части столбцов видим наличие пропущенных значений. Переименованы 2 столбца -'puNumber' в 'pu_number' и 'nonrefundable_support' в 'non_refundable_support'.***

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# С загрузкой и объединением данных все супер
#
# </div>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   7486 non-null   object
#  1   pu_number               7486 non-null   object
#  2   show_start_date         7486 non-null   object
#  3   type                    7486 non-null   object
#  4   film_studio             7468 non-null   object
#  5   production_country      7484 non-null   object
#  6   director                7477 non-null   object
#  7   producer                6918 non-null   object
#  8   age_restriction         7486 non-null   object
#  9   refundable_support      332 non-null    float64
#  10  non_refundable_support  332 non-null    float64
#  11  budget                  332 non-null    float64
#  12  financing_source        332 non-null    object
#  13  ratings                 6519 non-null   object
#  14  genres                  6510 non-null   object
#  15  box_office              3158 non-null   float64
# dtypes: float64(4), object(12)
# memory usage: 994.2+ KB

# %% [markdown]
# Рассмотрим данные в столбце 'ratings'-райтинг фильма на КиноПоиске.

# %%
data['ratings'].unique()
# Out:
# array(['7.2', '6.6', '6.8', '7.7', '8.3', '8.0', '7.8', '8.1', '7.1',
#        '6.0', '7.4', '5.8', '8.7', '6.3', '6.9', '5.0', '4.3', '7.3',
#        '7.0', '6.4', nan, '8.2', '7.5', '6.7', '7.9', '5.9', '6.2', '5.6',
#        '6.5', '2.4', '7.6', '6.1', '8.6', '8.5', '8.8', '5.5', '5.1',
#        '5.7', '5.4', '99%', '4.4', '4.5', '5.3', '4.1', '8.4', '2.6',
#        '3.8', '4.6', '4.8', '4.0', '3.0', '1.6', '4.2', '5.2', '4.7',
#        '4.9', '3.9', '2.7', '3.3', '2.9', '28%', '3.7', '1.4', '3.1',
#        '97%', '3.5', '3.2', '2.8', '1.5', '2.1', '2.5', '9.2', '3.4',
#        '1.1', '3.6', '83%', '64%', '91%', '94%', '62%', '79%', '90%',
#        '19%', '88%', '1.0', '89%', '1.3', '1.9', '1.8', '1.2', '1.7',
#        '9.0', '98%', '8.9', '9.1'], dtype=object)

# %% [markdown]
# Данные неоднородны, встречается знак %. Уберем знак %, после чего изменим тип данных в столбце на 'float', чтобы в дальнейших исследованиях работать с числовыми данными.

# %%
data['ratings']=data['ratings'].astype('str')

# %%
data['ratings']=[_.replace('%','') for _ in data['ratings']]

# %%
data['ratings'].unique()
# Out:
# array(['7.2', '6.6', '6.8', '7.7', '8.3', '8.0', '7.8', '8.1', '7.1',
#        '6.0', '7.4', '5.8', '8.7', '6.3', '6.9', '5.0', '4.3', '7.3',
#        '7.0', '6.4', 'nan', '8.2', '7.5', '6.7', '7.9', '5.9', '6.2',
#        '5.6', '6.5', '2.4', '7.6', '6.1', '8.6', '8.5', '8.8', '5.5',
#        '5.1', '5.7', '5.4', '99', '4.4', '4.5', '5.3', '4.1', '8.4',
#        '2.6', '3.8', '4.6', '4.8', '4.0', '3.0', '1.6', '4.2', '5.2',
#        '4.7', '4.9', '3.9', '2.7', '3.3', '2.9', '28', '3.7', '1.4',
#        '3.1', '97', '3.5', '3.2', '2.8', '1.5', '2.1', '2.5', '9.2',
#        '3.4', '1.1', '3.6', '83', '64', '91', '94', '62', '79', '90',
#        '19', '88', '1.0', '89', '1.3', '1.9', '1.8', '1.2', '1.7', '9.0',
#        '98', '8.9', '9.1'], dtype=object)

# %%
#number=[]
#for item in data['ratings']:
 #   number.append(float(item))
#data['ratings']=number

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера ⚠️</b>
#
# > [_.replace('%','') for _ in data['ratings']]
#
# > for item in data['ratings']:
#
# Не нужно работать с отдельными элементами датафрейма, потому что такой код может долго выполняться. Лучше использовать методы библиотеки pandas, так как что они оптимизированы.
#
# Замену можно сделать с помощью [str.replace](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html), а зачем нам цикл я не понял, если ниже все равно используешь .astype('float').
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Да, цикл здесь лишний, убрала. С методом str.replace еще буду разбираться.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Здорово, что внесла изменения в работу!
#
# </div>

# %%
data['ratings']=data['ratings'].astype('float')

# %%
data['ratings']
# Out:
# 0      7.20
# 1      6.60
# 2      6.80
# 3      6.80
# 4      6.80
#        ...
# 7481    NaN
# 7482   5.40
# 7483    NaN
# 7484    NaN
# 7485   6.30
# Name: ratings, Length: 7486, dtype: float64

# %% [markdown]
# Приводим к типу даты дату публикации 'show_start_date' - дата премьеры фильма.

# %%
data['show_start_date']=pd.to_datetime(data['show_start_date'], format='%Y-%m-%dT%H:%M:%S')
data['show_start_date']
# Out:
# 0      2015-11-27 12:00:00+00:00
# 1      2016-09-13 12:00:00+00:00
# 2      2016-10-10 12:00:00+00:00
# 3      2016-06-10 12:00:00+00:00
# 4      2015-07-29 12:00:00+00:00
#                   ...
# 7481   2019-12-23 12:00:00+00:00
# 7482   2019-12-24 12:00:00+00:00
# 7483   2019-12-28 12:00:00+00:00
# 7484   2019-12-30 12:00:00+00:00
# 7485   2019-12-30 12:00:00+00:00
# Name: show_start_date, Length: 7486, dtype: datetime64[ns, UTC]

# %% [markdown]
# Методом datetime() превращаем в понятные для Python даты из типа object в тип datetime в столбце show_start_date -дата премьеры фильма.
#
# Данные в столбце ratings-райтинг фильма на КиноПоиске привели к типу float.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# 👍
# </div>

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %% [markdown]
# Посмотрим в каких столбцах какое количество данных пропущено.

# %%
data.isnull().sum()
# Out:
# title                        0
# pu_number                    0
# show_start_date              0
# type                         0
# film_studio                 18
# production_country           2
# director                     9
# producer                   568
# age_restriction              0
# refundable_support        7154
# non_refundable_support    7154
# budget                    7154
# financing_source          7154
# ratings                    967
# genres                     976
# box_office                4328
# dtype: int64

# %%
pd.DataFrame(round(data.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_b2dd1_row0_col0,#T_b2dd1_row1_col0,#T_b2dd1_row2_col0,#T_b2dd1_row3_col0,#T_b2dd1_row4_col0,#T_b2dd1_row5_col0,#T_b2dd1_row6_col0,#T_b2dd1_row8_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b2dd1_row7_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_b2dd1_row9_col0,#T_b2dd1_row10_col0,#T_b2dd1_row11_col0,#T_b2dd1_row12_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b2dd1_row13_col0,#T_b2dd1_row14_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_b2dd1_row15_col0{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }</style><table id="T_b2dd1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2dd1_level0_row0" class="row_heading level0 row0" >title</th>
#                         <td id="T_b2dd1_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row1" class="row_heading level0 row1" >pu_number</th>
#                         <td id="T_b2dd1_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row2" class="row_heading level0 row2" >show_start_date</th>
#                         <td id="T_b2dd1_row2_col0" class="data row2 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row3" class="row_heading level0 row3" >type</th>
#                         <td id="T_b2dd1_row3_col0" class="data row3 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row4" class="row_heading level0 row4" >film_studio</th>
#                         <td id="T_b2dd1_row4_col0" class="data row4 col0" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row5" class="row_heading level0 row5" >production_country</th>
#                         <td id="T_b2dd1_row5_col0" class="data row5 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row6" class="row_heading level0 row6" >director</th>
#                         <td id="T_b2dd1_row6_col0" class="data row6 col0" >0.100000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row7" class="row_heading level0 row7" >producer</th>
#                         <td id="T_b2dd1_row7_col0" class="data row7 col0" >7.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row8" class="row_heading level0 row8" >age_restriction</th>
#                         <td id="T_b2dd1_row8_col0" class="data row8 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row9" class="row_heading level0 row9" >refundable_support</th>
#                         <td id="T_b2dd1_row9_col0" class="data row9 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row10" class="row_heading level0 row10" >non_refundable_support</th>
#                         <td id="T_b2dd1_row10_col0" class="data row10 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row11" class="row_heading level0 row11" >budget</th>
#                         <td id="T_b2dd1_row11_col0" class="data row11 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row12" class="row_heading level0 row12" >financing_source</th>
#                         <td id="T_b2dd1_row12_col0" class="data row12 col0" >95.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row13" class="row_heading level0 row13" >ratings</th>
#                         <td id="T_b2dd1_row13_col0" class="data row13 col0" >12.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row14" class="row_heading level0 row14" >genres</th>
#                         <td id="T_b2dd1_row14_col0" class="data row14 col0" >13.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b2dd1_level0_row15" class="row_heading level0 row15" >box_office</th>
#                         <td id="T_b2dd1_row15_col0" class="data row15 col0" >57.800000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **1.2.2.1 Рассмотрим пропуски в столбце 'film_studio'- студия-производитель.**

# %%
data['film_studio'].isnull().sum()
# Out:
# 18

# %%
def nan_ratio (column):
    return  print('Пропущено {:.1%}'.format(data[column].isna().value_counts()[1]/len(data),2) +  'значений')

# %%
nan_ratio('film_studio')
# Out:
# Пропущено 0.2%значений

# %%
data.dropna(subset=['film_studio'], inplace=True)

# %%
data['film_studio'].isna().value_counts()
# Out:
# False    7468
# Name: film_studio, dtype: int64

# %% [markdown]
# В данных столбца с названием студии-производителя - film_studio было пропущено 18 или 0.2% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности или необязательное поле для заполнения, а также мог иметь место технический сбой.
#
# Пропущенные значения с названием студии-производителя были удалены, так как невозможно восстановить корректные значения и количество пропущенных значений составляет 0.2%, их удаление не приведет к искажению результатов исследования.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# В целом ты права, но если пропуски не мешают в работе, их лучше оставить. Еще можно использовать значение-заглушку (например "Неизвестно" или "undefined")
#
# </div>

# %% [markdown]
# **1.2.2.2 Рассмотрим пропуски в столбце 'production_country'- страна-производитель.**

# %%
data['production_country'].isnull().sum()
# Out:
# 1

# %%
nan_ratio('production_country')
# Out:
# Пропущено 0.0%значений

# %%
data.dropna(subset=['production_country'],inplace=True)

# %%
data['production_country'].isna().value_counts()
# Out:
# False    7467
# Name: production_country, dtype: int64

# %% [markdown]
# В данных столбца с названием страны-производителя - production_country было пропущено 1 или 0.0% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности, мог иметь место технический сбой.
#
# Пропущенные значения с названием страны-производителя были удалены, так как невозможно восстановить корректные значения и количество пропущенных значений составляет 0.0%, их удаление не приведет к искажению результатов исследования.

# %% [markdown]
# **1.2.2.3 Рассмотрим пропуски в столбце 'director'- режиссёр.**

# %%
data['director'].isnull().sum()
# Out:
# 8

# %%
nan_ratio('director')
# Out:
# Пропущено 0.1%значений

# %%
data.dropna(subset=['director'],inplace=True)

# %%
data['director'].isna().value_counts()
# Out:
# False    7459
# Name: director, dtype: int64

# %% [markdown]
# В данных столбца с именем режиссёра - director было пропущено 8 или 0.1% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности, возможно, необязательное поле для заполнения, а также мог иметь место технический сбой.
#
# Пропущенные значения с именем режиссёра были удалены, так как невозможно восстановить корректные значения и количество пропущенных значений составляет 0.1%, их удаление не приведет к искажению результатов исследования.

# %% [markdown]
# **1.2.2.4 Рассмотрим пропуски в столбце 'producer'- продюсер.**

# %%
data['producer'].isnull().sum()
# Out:
# 564

# %%
nan_ratio('producer')
# Out:
# Пропущено 7.6%значений

# %%
data['producer'].value_counts()
# Out:
# П.Смирнов                                                                        67
# Олег Кузовков, Дмитрий Ловейко, Марина Ратина                                    28
# С.Сельянов                                                                       18
# Д.Ловейко, О.Кузовков                                                            17
# А.Тельнов                                                                        11
#                                                                                  ..
# ЗАО "Киновидеообъединение "Крупный план"                                          1
# Майк Бек, Альваро Бакеро Бенедетти, Алекс Дрэйпер, Ричард В.Кинг, Энди Миттон     1
# Ави Арад                                                                          1
# Келли Броад, Воган Сивелл                                                         1
# Дон Кемпф, Анди Уд                                                                1
# Name: producer, Length: 5329, dtype: int64

# %%
data['producer']=data['producer'].fillna('unknown')

# %%
data['producer'].isna().value_counts()
# Out:
# False    7459
# Name: producer, dtype: int64

# %% [markdown]
# В данных столбца с именем продюсера - producer было пропущено 564 или 7.6% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности, но, скорее всего, это необязательное поле для заполнения, а также мог иметь место технический сбой.
#
# Пропущенные значения с именем продюсера были заменены на значение 'unknown', так как невозможно восстановить корректные значения.

# %% [markdown]
# **1.2.2.5 Рассмотрим пропуски в столбце 'refundable_support'- объем возвратных средств государственной поддержки.**

# %%
data['refundable_support'].isnull().sum()
# Out:
# 7127

# %%
nan_ratio('refundable_support')
# Out:
# Пропущено 95.5%значений

# %%
data['refundable_support'].unique()
# Out:
# array([         nan, 0.000000e+00, 5.000000e+07, 2.600000e+07,
#        3.000000e+07, 1.500000e+07, 1.000000e+07, 2.000000e+07,
#        7.153119e+06, 2.500000e+07, 4.000000e+07, 6.000000e+07,
#        4.400000e+07, 2.900000e+07, 4.100000e+07, 3.600000e+07,
#        3.500000e+06, 5.000000e+06, 1.900000e+07, 9.000000e+06,
#        1.100000e+08, 1.700000e+07, 7.500000e+07, 1.500000e+08,
#        3.800000e+07, 1.000000e+08, 5.500000e+07, 7.000000e+06,
#        7.346881e+06, 8.000000e+06, 1.150000e+08, 3.500000e+07,
#        1.800000e+08, 2.800000e+07, 8.000000e+07])

# %% [markdown]
# В данных столбца refundable_support -объём возвратных средств государственной поддержки было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку.
#
# Пропущенные значения объёмов возвратных средств государственной поддержки оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.

# %% [markdown]
# **1.2.2.6 Рассмотрим пропуски в столбце 'non_refundable_support'- объем невозвратных средств государственной поддержки.**

# %%
nan_ratio('non_refundable_support')
# Out:
# Пропущено 95.5%значений

# %%
data['refundable_support'].unique()
# Out:
# array([         nan, 0.000000e+00, 5.000000e+07, 2.600000e+07,
#        3.000000e+07, 1.500000e+07, 1.000000e+07, 2.000000e+07,
#        7.153119e+06, 2.500000e+07, 4.000000e+07, 6.000000e+07,
#        4.400000e+07, 2.900000e+07, 4.100000e+07, 3.600000e+07,
#        3.500000e+06, 5.000000e+06, 1.900000e+07, 9.000000e+06,
#        1.100000e+08, 1.700000e+07, 7.500000e+07, 1.500000e+08,
#        3.800000e+07, 1.000000e+08, 5.500000e+07, 7.000000e+06,
#        7.346881e+06, 8.000000e+06, 1.150000e+08, 3.500000e+07,
#        1.800000e+08, 2.800000e+07, 8.000000e+07])

# %%
data['budget'].isnull().sum()
# Out:
# 7127

# %% [markdown]
# В данных столбца nun_refundable_support -объём невозвратных средств государственной поддержки было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку.
#
# Пропущенные значения объёмов возвратных средств негосударственной поддержки оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.

# %% [markdown]
# **1.2.2.7 Рассмотрим пропуски в столбце 'budget'- общий бюджет фильма.**

# %%
data['budget'].isnull().sum()
# Out:
# 7127

# %%
nan_ratio('budget')
# Out:
# Пропущено 95.5%значений

# %% [markdown]
# В данных столбца budget -общий бюджет фильма было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку.
#
# Пропущенные значения общего бюджета фильма оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.

# %% [markdown]
# **1.2.2.8 Рассмотрим пропуски в столбце 'financing_source'- источник государственного финансирования.**

# %%
data['financing_source'].isnull().sum()
# Out:
# 7127

# %%
nan_ratio('financing_source')
# Out:
# Пропущено 95.5%значений

# %%
data['financing_source'].value_counts()
# Out:
# Министерство культуры               164
# Фонд кино                           146
# Министерство культуры, Фонд кино     22
# Name: financing_source, dtype: int64

# %% [markdown]
# В данных столбца financing_source -источник государственного финансирования было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку.
#
# Пропущенные значения источников государственного финансирования оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.

# %% [markdown]
# **1.2.2.8 Рассмотрим пропуски в столбце 'box_office'- сборы в рублях.**

# %%
data['box_office'].isnull().sum()
# Out:
# 4304

# %%
nan_ratio('box_office')
# Out:
# Пропущено 57.7%значений

# %%
data['box_office'].unique()
# Out:
# array([           nan, 2.70000000e+03, 3.60000000e+02, ...,
#        3.14379050e+06, 1.80017724e+07, 2.19569000e+05])

# %% [markdown]
# В данных столбца box_office -сборы в рублях было пропущено 4304 или 57.7 % значений. Можно предположить, что статистика по сборам велась не по всем фильмам или в наше распоряжение попала только часть информации.
#
# Пропущенные значения сборов в рублях оставлены незаполненными. Дальнейшие исследования для фильмов, по сборам от проката которых имеются данные, будут проводится с учетом отсутствия информации по остальным фильмам.

# %% [markdown]
# **1.2.2.9 Рассмотрим пропуски в столбце 'ratings'- рейтинг фильма на КиноПоиске.**

# %%
data['ratings'].isnull().sum()
# Out:
# 948

# %%
nan_ratio('ratings')
# Out:
# Пропущено 12.7%значений

# %% [markdown]
# Посмотрим срез данных, где рейтинг фильмов больше или равен 10.

# %%
data[(data.ratings>=10)]
# Out:
#                                                   title  pu_number  \
# 259                                             Прошлое  221030715
# 811                                           От винта!  114000212
# 1053                                   Песочный человек  121029212
# 1341                               Сказка о добре и Вре  111008913
# 1805                                           Спираль.  111001014
# 1874                         Короткие истории о любви 2  121002615
# 1899  Золушка /По сказке Шарля Перро/. Холодное торж...  121003615
# 2126                                   Поездка к матери  111002015
# 2146                                            Главный  111003415
# 2438                                    Самый рыжий Лис  111012715
# 2680                                   Год Белого Слона  111003915
# 3139                                      Я умею вязать  111019615
# 3431                                             Наурыз  131000217
# 3439                                 Семь диких историй  126005916
# 3446                       Короткие истории о любви - 4  126006316
# 3514                                          Чужой дом  111015516
# 3585  Машины Страшилки. Серия "Жутчайшая повесть о п...  114003916
# 3786                                           Охотники  111017816
# 3948                                             Круиз.  211038210
# 5332                                            Добыча.  121009411
# 5455                                       Вечный холод  111006417
# 5821                                             Свинья  121007018
# 5910                                               Мира  112000118
# 6426      Памятные даты России. Партизаны и подпольщики  112013018
# 6616                             ОТ ВОЙНЫ ДО НАШИХ ДНЕЙ  111026518
# 6737                                     Колесо времени  111003219
# 6882                          Животные рядом со Святыми  112003719
# 7159                    Анна Каренина. Интимный дневник  111013919
# 7277                                             Добыча  121028319
#
#                show_start_date             type  \
# 259  2015-07-29 12:00:00+00:00   Художественный
# 811  2012-08-06 12:00:00+00:00     Анимационный
# 1053 2012-11-29 12:00:00+00:00   Художественный
# 1341 2013-11-15 12:00:00+00:00   Художественный
# 1805 2014-01-30 12:00:00+00:00   Художественный
# 1874 2015-02-13 12:00:00+00:00   Художественный
# 1899 2015-02-27 12:00:00+00:00   Художественный
# 2126 2015-03-02 12:00:00+00:00   Художественный
# 2146 2015-03-27 12:00:00+00:00   Художественный
# 2438 2015-07-30 12:00:00+00:00   Художественный
# 2680 2015-04-08 12:00:00+00:00   Художественный
# 3139 2015-11-27 12:00:00+00:00   Художественный
# 3431 2017-03-09 12:00:00+00:00   Художественный
# 3439 2016-11-28 12:00:00+00:00           Прочие
# 3446 2016-12-30 12:00:00+00:00           Прочие
# 3514 2016-09-14 12:00:00+00:00   Художественный
# 3585 2016-12-09 12:00:00+00:00     Анимационный
# 3786 2016-02-06 12:00:00+00:00   Художественный
# 3948 2010-09-03 12:00:00+00:00   Художественный
# 5332 2011-06-15 12:00:00+00:00   Художественный
# 5455 2017-08-28 12:00:00+00:00   Художественный
# 5821 2018-04-11 12:00:00+00:00   Художественный
# 5910 2018-06-04 12:00:00+00:00   Документальный
# 6426 2018-11-28 12:00:00+00:00   Документальный
# 6616 2019-01-21 12:00:00+00:00   Художественный
# 6737 2019-03-01 12:00:00+00:00   Художественный
# 6882 2019-05-03 12:00:00+00:00   Документальный
# 7159 2019-10-23 12:00:00+00:00   Художественный
# 7277 2019-10-03 12:00:00+00:00   Художественный
#
#                                             film_studio  \
# 259   20 Сенчюри Фокс де Архентина, Чемо, ЭйчБи Филм...
# 811                   ЗАО "Продюсерский центр "Парадиз"
# 1053                            Спотлайт Медиа Продакшн
# 1341                     НП "Студия игрового кино "Лик"
# 1805                               ООО "Компания Питон"
# 1874  Кавиар, Курт 13, СтритЛайт Филмз, Нэйер Дойче ...
# 1899                    Женр Филмз, Уолт Дисней Пикчерз
# 2126                         ЗАО "Киностудия "М"-Фильм"
# 2146                           ООО "Киностудия "МАСТЕР"
# 2438                 ООО "Продюсерский центр "Ленфильм"
# 2680                    ООО "Творческое объединение ЮГ"
# 3139                                ООО "Белое Зеркало"
# 3431                                             Эс Джи
# 3439  Макс Бэйкер, Джон Е.Брайан, Пьер-Луи Гарнон,  ...
# 3446  Нетворг Айлэнд Телевижн, Магнетфильм, Шорткатс...
# 3514                                ООО "Лига Продакшн"
# 3585           ООО Студия "АНИМАККОРД", АНИМАККОРД ЛТД.
# 3786                Селиверстов Александр Александрович
# 3948                ООО "ЮНАЙТЕД МУЛЬТИМЕДИА ПРОДЖЕКТС"
# 5332                                   Афтер Дарк Филмз
# 5455  ЗАО "Производственный комплекс "ГЛАВКИНО", ООО...
# 5821    Дарк Прекёрсор Продакшен, Филмиран, Хедейт Филм
# 5910                         ООО "Компания "Новые люди"
# 6426                          ООО Кинокомпания "Вектор"
# 6616                  ИП Вайсман Анатолий Александрович
# 6737                                    ООО "БестМедиа"
# 6882                       ООО "Кинопрограмма "XXI век"
# 7159                                          ООО "РТВ"
# 7277  Блумхаус Продакшнз, Хайд Парк Интертейнмент, Т...
#
#                                      production_country  \
# 259                                Аргентина - Бразилия
# 811                                              Россия
# 1053                                          Швейцария
# 1341                                             Россия
# 1805                                             Россия
# 1874  Нидерланды - США - Германия - Канада - Франция...
# 1899                                                США
# 2126                                             Россия
# 2146                                             Россия
# 2438                                             Россия
# 2680                                             Россия
# 3139                                             Россия
# 3431                               Республика Казахстан
# 3439                       США - Пуэрто-Рико - Франция
# 3446  Великобритания - Аргентина - США - Франция - Р...
# 3514                  Россия, Грузия, Хорватия, Испания
# 3585                            Россия, Республика Кипр
# 3786                                             Россия
# 3948                                             Россия
# 5332                                                США
# 5455                                             Россия
# 5821                                               Иран
# 5910                                             Россия
# 6426                                             Россия
# 6616                                             Россия
# 6737                                             Россия
# 6882                                             Россия
# 7159                                             Россия
# 7277                                                США
#
#                                                director  \
# 259                                       Эктор Бабенко
# 811                                            О.Лопато
# 1053                                        Питер Луизи
# 1341                                          Е.Шиляева
# 1805                                           А.Волгин
# 1874  Мэтью Аувро, Лео Брайдл, Бен Бренд, Ден Кларк,...
# 1899                                       Кеннет Брана
# 2126                                 М.Косырев-Нестеров
# 2146                                             Ю.Кара
# 2438                                        А.Стреляная
# 2680                                           Ю.Грымов
# 3139                  Н.Степанова при участии С.Иванова
# 3431                                     Аскар Бисембин
# 3439  М.Бэйкер, Д.Е.Брайант, Д.Рондот, Я.Серсар, Д.С...
# 3446  Д.Адар, П.Антохин, М.Биасин, А.Бурунова, К.Кол...
# 3514                                       Р.Глурджидзе
# 3585                                         Д.Червяцов
# 3786                                      А.Селиверстов
# 3948                                        И.Ромащенко
# 5332                                    Патрик Сиверсен
# 5455                                          А.Мигачев
# 5821                                        Мани Хагиги
# 5910                                           Д.Шабаев
# 6426                             Н.Иванова, А.Кузнецова
# 6616  А.Сазонов, Е.Климович, А.Коломеец, С.Черникова...
# 6737                                         Б.Куломзин
# 6882                                         Т.Мирошник
# 7159                                           Ю.Грымов
# 7277                                       Франк Халфун
#
#                                                producer  \
# 259            Эктор Бабенко, Оскар Крамер, Хуго Сидмэн
# 811                 Г.Нерсисян, А.Манасарян, А.Нерсесян
# 1053                           Дэвид Луизи, Питер Луизи
# 1341                                        К.Терещенко
# 1805                                         Е.Ковалева
# 1874  Мэри Пэт Бентел, Бен Бренд, Сиара Гиллан, Джор...
# 1899       Дэвид Бэррон, Саймон Кинберг, Эллисон Ширмур
# 2126                                 М.Косырев-Нестеров
# 2146                                             Ю.Кара
# 2438                           А.Котелевский, Э.Пичугин
# 2680                                          П.Поляков
# 3139                          С.Кикнавелидзе, Д.Улюкаев
# 3431                 Олег Головашкин, Алмас Султангазин
# 3439  М.Бэйкер, Д.Е.Брайан, П.-Л.Гарнон, М.Х.Дельгад...
# 3446  Д.Адар, Д.Амсон, П.Антохин, А.Армстронг, С.Бил...
# 3514        З.Магалашвили, К.Гечмен-Вальдек, Н.Горшкова
# 3585                              Д.Ловейко, О.Кузовков
# 3786                 Е.Тарковская, Т.Лагода, Д.Степанян
# 3948                                     Р.Атамалибеков
# 5332                        Закари Ти Брайан, Кристофер
# 5455                                          И.Бачурин
# 5821                                        Мани Хагиги
# 5910                                        Н.Мокрицкая
# 6426                                        В.Коханович
# 6616  Д.Руюежин, Л.Пятницкая, Д.Колеров, Э.Ким, А.Хомич
# 6737                                         Б.Куломзин
# 6882                               В.Есинов, Е.Калинина
# 7159                                           Ю.Грымов
# 7277         Ашок Амритрадж, Джейсон Блум, Трэвис Клафф
#
#                              age_restriction  refundable_support  \
# 259          «16+» - для детей старше 16 лет                 NaN
# 811          «12+» - для детей старше 12 лет                 NaN
# 1053         «16+» - для детей старше 16 лет                 NaN
# 1341           «6+» - для детей старше 6 лет                 NaN
# 1805         «12+» - для детей старше 12 лет                 NaN
# 1874             «18+» - запрещено для детей                 NaN
# 1899           «6+» - для детей старше 6 лет                 NaN
# 2126         «16+» - для детей старше 16 лет                 NaN
# 2146           «6+» - для детей старше 6 лет                0.00
# 2438           «6+» - для детей старше 6 лет                 NaN
# 2680           «6+» - для детей старше 6 лет                 NaN
# 3139         «16+» - для детей старше 16 лет                0.00
# 3431         «12+» - для детей старше 12 лет                 NaN
# 3439             «18+» - запрещено для детей                 NaN
# 3446             «18+» - запрещено для детей                 NaN
# 3514         «12+» - для детей старше 12 лет                 NaN
# 3585  «0+» - для любой зрительской аудитории                 NaN
# 3786         «16+» - для детей старше 16 лет                 NaN
# 3948         «16+» - для детей старше 16 лет                 NaN
# 5332             «18+» - запрещено для детей                 NaN
# 5455             «18+» - запрещено для детей                 NaN
# 5821             «18+» - запрещено для детей                 NaN
# 5910             «18+» - запрещено для детей                 NaN
# 6426         «12+» - для детей старше 12 лет                 NaN
# 6616         «12+» - для детей старше 12 лет                 NaN
# 6737           «6+» - для детей старше 6 лет                 NaN
# 6882  «0+» - для любой зрительской аудитории                 NaN
# 7159         «16+» - для детей старше 16 лет                 NaN
# 7277         «16+» - для детей старше 16 лет                 NaN
#
#       non_refundable_support        budget       financing_source  ratings  \
# 259                      NaN           NaN                    NaN    99.00
# 811                      NaN           NaN                    NaN    28.00
# 1053                     NaN           NaN                    NaN    97.00
# 1341                     NaN           NaN                    NaN    99.00
# 1805                     NaN           NaN                    NaN    99.00
# 1874                     NaN           NaN                    NaN    83.00
# 1899                     NaN           NaN                    NaN    64.00
# 2126                     NaN           NaN                    NaN    91.00
# 2146           10,000,000.00 40,000,000.00  Министерство культуры    94.00
# 2438                     NaN           NaN                    NaN    62.00
# 2680                     NaN           NaN                    NaN    79.00
# 3139            4,700,000.00 14,462,464.00  Министерство культуры    90.00
# 3431                     NaN           NaN                    NaN    19.00
# 3439                     NaN           NaN                    NaN    88.00
# 3446                     NaN           NaN                    NaN    83.00
# 3514                     NaN           NaN                    NaN    91.00
# 3585                     NaN           NaN                    NaN    97.00
# 3786                     NaN           NaN                    NaN    89.00
# 3948                     NaN           NaN                    NaN    97.00
# 5332                     NaN           NaN                    NaN    88.00
# 5455                     NaN           NaN                    NaN    83.00
# 5821                     NaN           NaN                    NaN    94.00
# 5910                     NaN           NaN                    NaN    94.00
# 6426                     NaN           NaN                    NaN    91.00
# 6616                     NaN           NaN                    NaN    98.00
# 6737                     NaN           NaN                    NaN    98.00
# 6882                     NaN           NaN                    NaN    99.00
# 7159                     NaN           NaN                    NaN    79.00
# 7277                     NaN           NaN                    NaN    88.00
#
#                            genres     box_office
# 259           ужасы,триллер,драма            NaN
# 811   детский,приключения,комедия       1,740.00
# 1053     ужасы,фантастика,фэнтези            NaN
# 1341       триллер,драма,детектив            NaN
# 1805       аниме,мультфильм,ужасы       4,295.00
# 1874                          NaN   1,429,859.00
# 1899     мюзикл,фэнтези,мелодрама 528,732,557.70
# 2126               драма,семейный           0.00
# 2146    фантастика,боевик,комедия     334,750.00
# 2438             фэнтези,семейный            NaN
# 2680                     семейный            NaN
# 3139                        драма     801,370.00
# 3431                      комедия      37,960.00
# 3439                          NaN   1,025,937.00
# 3446                          NaN   2,266,408.00
# 3514                        драма            NaN
# 3585     мультфильм,ужасы,фэнтези            NaN
# 3786    фантастика,комедия,боевик      82,840.00
# 3948  приключения,комедия,фэнтези            NaN
# 5332    фантастика,боевик,триллер            NaN
# 5455       фэнтези,боевик,триллер            NaN
# 5821                триллер,драма   1,587,221.51
# 5910                        драма            NaN
# 6426              драма,биография            NaN
# 6616            фантастика,боевик            NaN
# 6737          фэнтези,приключения      34,992.00
# 6882               криминал,драма            NaN
# 7159                        драма     182,882.50
# 7277    фантастика,боевик,триллер   4,416,590.45

# %% [markdown]
# Приводим выбивающиеся данные, разделив на 10. и проверяем.

# %%
data.loc[data['ratings']>=10,'ratings']=data.loc[data['ratings']>=10,'ratings']/10

# %%
data[(data.ratings>=10)]
# Out:
# Empty DataFrame
# Columns: [title, pu_number, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, non_refundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %%
data['ratings'].unique()
# Out:
# array([7.2, 6.6, 6.8, 7.7, 8.3, 8. , 7.8, 8.1, 7.1, 6. , 7.4, 5.8, 8.7,
#        6.3, 6.9, 5. , 4.3, 7.3, 7. , 6.4, nan, 8.2, 7.5, 6.7, 7.9, 5.9,
#        6.2, 5.6, 6.5, 2.4, 7.6, 6.1, 8.6, 8.5, 8.8, 5.5, 5.1, 5.7, 5.4,
#        9.9, 4.4, 4.5, 5.3, 4.1, 8.4, 2.6, 3.8, 4.6, 4.8, 4. , 3. , 1.6,
#        4.2, 5.2, 4.7, 4.9, 3.9, 2.7, 3.3, 2.9, 2.8, 3.7, 1.4, 3.1, 9.7,
#        3.5, 3.2, 1.5, 2.1, 2.5, 9.2, 3.4, 1.1, 3.6, 9.1, 9.4, 9. , 1.9,
#        1. , 8.9, 1.3, 1.8, 1.2, 1.7, 9.8])

# %%
data['ratings'].describe()
# Out:
# count   6,511.00
# mean        6.49
# std         1.11
# min         1.00
# 25%         5.90
# 50%         6.60
# 75%         7.20
# max         9.90
# Name: ratings, dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера ❗</b>
#
# Не нужно заполнять пропуски в ratings, это очень субъективный признак
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Да, согласна, были по этим данным большие сомнения по заполнению. Оставила незаполненными.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Замечательно!
# </div>

# %% [markdown]
# В данных столбца ratings -рейтинг фильма на КиноПоиске было пропущено 948 или 12.7 % значений. Можно предположить, имел место человеческий фактор - не все данные заполнялись, либо данная информация была необязательна для заполнения, возможно, технический сбой. Часть заполненных данных отображалась некорректно.
#
# Пропущенные значения рейтинга фильма на КиноПоиске оставлены незаполненными, так как невозможно заменить корректными значениями.

# %% [markdown]
# **1.2.2.10 Рассмотрим пропуски в столбце 'genres'- жанр фильма.**

# %%
data['genres'].isnull().sum()
# Out:
# 957

# %%
nan_ratio('genres')
# Out:
# Пропущено 12.8%значений

# %%
data['genres'].unique()
# Out:
# array(['боевик,драма,мелодрама', 'драма,военный',
#        'фантастика,боевик,триллер', 'драма', 'мелодрама,комедия',
#        'мюзикл,мелодрама,комедия', 'комедия,криминал',
#        'боевик,триллер,детектив', 'боевик,драма,приключения',
#        'драма,спорт', 'триллер,драма,мелодрама', 'комедия,мелодрама',
#        'драма,мелодрама,комедия', 'драма,мелодрама', 'драма,история',
#        'драма,мелодрама,семейный', 'комедия,мелодрама,криминал',
#        'комедия', 'боевик,драма,криминал', 'драма,комедия',
#        'ужасы,фантастика,комедия', 'мультфильм,короткометражка,мелодрама',
#        'драма,криминал', 'мультфильм,фантастика,фэнтези',
#        'триллер,драма,криминал', 'драма,мелодрама,биография',
#        'драма,комедия,военный', 'фантастика,драма,детектив',
#        'мюзикл,семейный', nan, 'военный,приключения,драма',
#        'документальный,драма', 'драма,биография,история',
#        'боевик,триллер,драма', 'фэнтези,боевик',
#        'боевик,комедия,криминал', 'мюзикл,комедия,детский',
#        'комедия,мелодрама,драма', 'мультфильм,фэнтези,комедия',
#        'комедия,история', 'мелодрама', 'драма,биография,музыка',
#        'фэнтези,драма,мелодрама', 'триллер,военный',
#        'драма,мелодрама,военный', 'мюзикл,драма,мелодрама',
#        'мюзикл,комедия', 'мультфильм,приключения,семейный',
#        'ужасы,триллер', 'боевик,драма,военный', 'драма,боевик',
#        'мультфильм,драма,комедия', 'триллер,криминал',
#        'военный,биография,драма', 'комедия,семейный', 'военный',
#        'драма,семейный,биография', 'фэнтези,приключения,семейный',
#        'драма,криминал,биография', 'ужасы,триллер,детектив',
#        'боевик,история,драма', 'ужасы,триллер,драма',
#        'драма,криминал,спорт', 'документальный,короткометражка',
#        'триллер,драма', 'криминал,детектив,приключения',
#        'драма,комедия,криминал', 'драма,комедия,вестерн',
#        'драма,мелодрама,детектив', 'мелодрама,биография',
#        'фэнтези,мелодрама,драма', 'драма,мелодрама,история',
#        'комедия,приключения,история', 'приключения', 'драма,семейный',
#        'криминал,детектив', 'мультфильм,короткометражка,ужасы',
#        'фантастика,триллер,драма', 'фэнтези,мелодрама,комедия',
#        'драма,биография', 'комедия,криминал,история',
#        'триллер,драма,детектив', 'фантастика,комедия,приключения',
#        'фэнтези,семейный', 'ужасы,фантастика,боевик',
#        'мелодрама,криминал', 'комедия,приключения,мелодрама',
#        'боевик,триллер,приключения', 'боевик,приключения',
#        'боевик,триллер,криминал', 'документальный,военный,история',
#        'драма,музыка', 'боевик,драма', 'приключения,боевик',
#        'драма,военный,биография', 'триллер,драма,приключения',
#        'аниме,мультфильм,фэнтези', 'триллер,детектив,драма',
#        'боевик,триллер,мелодрама', 'боевик,история',
#        'приключения,история', 'драма,комедия,приключения',
#        'фэнтези,комедия,приключения', 'драма,вестерн',
#        'документальный,музыка', 'мелодрама,драма',
#        'триллер,криминал,детектив', 'ужасы', 'боевик,комедия,приключения',
#        'мультфильм,фэнтези,боевик', 'боевик,фэнтези,драма',
#        'фэнтези,драма', 'фэнтези,боевик,комедия',
#        'приключения,детский,комедия', 'документальный',
#        'боевик,триллер,комедия', 'мелодрама,комедия,криминал',
#        'драма,детектив', 'мюзикл,ужасы,триллер', 'детектив,триллер,ужасы',
#        'ужасы,фэнтези', 'ужасы,фэнтези,триллер', 'мультфильм,драма',
#        'ужасы,боевик,фантастика', 'боевик', 'фантастика,боевик',
#        'мелодрама,комедия,приключения', 'триллер,детектив',
#        'мюзикл,мелодрама,фэнтези', 'криминал', 'триллер,комедия,криминал',
#        'боевик,приключения,триллер', 'триллер,драма,военный',
#        'комедия,семейный,музыка', 'комедия,фантастика,мелодрама',
#        'фантастика,триллер,криминал', 'комедия,драма', 'боевик,военный',
#        'ужасы,фантастика,триллер', 'фантастика,драма,мелодрама',
#        'фэнтези,драма,детектив', 'боевик,триллер', 'боевик,драма,история',
#        'мультфильм,мюзикл,фэнтези', 'для взрослых,драма,мелодрама',
#        'мультфильм,боевик,детектив', 'фантастика,мелодрама,боевик',
#        'ужасы,фантастика,детектив', 'фантастика,боевик,приключения',
#        'мелодрама,комедия,спорт', 'комедия,боевик,приключения',
#        'документальный,приключения', 'мультфильм,короткометражка,детский',
#        'комедия,приключения', 'ужасы,драма', 'ужасы,фэнтези,боевик',
#        'мультфильм,фэнтези,детский', 'мюзикл,боевик,драма',
#        'семейный,комедия,драма', 'концерт,музыка', 'фэнтези,боевик,драма',
#        'драма,комедия,музыка', 'фантастика,фэнтези,боевик',
#        'фэнтези,комедия,семейный', 'фэнтези,драма,комедия',
#        'мультфильм,мюзикл,драма', 'триллер', 'боевик,криминал,триллер',
#        'мультфильм,приключения,драма', 'мелодрама,музыка',
#        'документальный,музыка,концерт', 'мультфильм,семейный',
#        'мультфильм,комедия,приключения', 'мультфильм,комедия,семейный',
#        'фантастика,драма', 'фэнтези,боевик,приключения',
#        'мультфильм,приключения', 'драма,военный,история', 'история',
#        'драма,приключения,военный',
#        'документальный,короткометражка,семейный',
#        'мелодрама,история,триллер', 'ужасы,детектив',
#        'мюзикл,комедия,приключения', 'драма,спорт,биография',
#        'фантастика,боевик,комедия', 'фантастика,приключения,детектив',
#        'короткометражка,драма,военный', 'драма,мультфильм',
#        'приключения,семейный', 'детектив', 'триллер,приключения',
#        'аниме,мультфильм,боевик', 'драма,комедия,биография',
#        'драма,комедия,спорт', 'боевик,мелодрама,комедия',
#        'семейный,комедия', 'фэнтези,боевик,триллер',
#        'документальный,фэнтези,семейный', 'фантастика,фэнтези,драма',
#        'ужасы,комедия,фэнтези', 'документальный,биография,музыка',
#        'фантастика,боевик,фэнтези', 'ужасы,боевик,триллер',
#        'комедия,криминал,семейный', 'приключения,драма',
#        'криминал,драма,триллер', 'драма,детектив,криминал',
#        'фэнтези,приключения,комедия', 'комедия,спорт',
#        'мюзикл,фэнтези,мелодрама', 'мультфильм,фэнтези,приключения',
#        'фантастика,фэнтези,приключения', 'фэнтези',
#        'фэнтези,приключения,боевик', 'фантастика,боевик,драма',
#        'криминал,драма', 'криминал,триллер,драма',
#        'драма,мелодрама,приключения', 'детский,комедия',
#        'фантастика,драма,боевик', 'мультфильм,семейный,фэнтези',
#        'концерт,музыка,документальный', 'ужасы,комедия,приключения',
#        'драма,мелодрама,криминал', 'ужасы,фантастика,фэнтези',
#        'боевик,комедия', 'мультфильм,фантастика,комедия', 'триллер,ужасы',
#        'мультфильм,мюзикл,комедия', 'мелодрама,фэнтези,триллер',
#        'детский,приключения,комедия', 'комедия,детектив',
#        'аниме,мультфильм,мелодрама', 'документальный,драма,семейный',
#        'документальный,биография,история', 'военный,боевик,драма',
#        'ужасы,комедия', 'комедия,приключения,семейный',
#        'приключения,биография,история', 'детский,приключения,семейный',
#        'спорт,драма,биография', 'аниме,мультфильм,ужасы',
#        'фантастика,боевик,криминал', 'мюзикл,драма',
#        'драма,криминал,детектив', 'аниме,мультфильм,драма',
#        'драма,триллер,приключения', 'триллер,криминал,драма',
#        'фэнтези,комедия,драма', 'мультфильм,комедия',
#        'драма,комедия,история', 'комедия,биография,история',
#        'мультфильм,фантастика,приключения', 'аниме,мультфильм,фантастика',
#        'мультфильм,фэнтези,семейный', 'мультфильм,боевик,комедия',
#        'комедия,криминал,спорт', 'документальный,мюзикл',
#        'мелодрама,комедия,музыка', 'биография',
#        'триллер,криминал,комедия', 'фантастика,драма,комедия',
#        'комедия,драма,мелодрама', 'фантастика,приключения,боевик',
#        'мультфильм,фэнтези,драма', 'триллер,комедия',
#        'драма,приключения,биография', 'фантастика,комедия',
#        'мелодрама,драма,комедия', 'боевик,криминал',
#        'драма,криминал,боевик', 'мультфильм,мюзикл,детский',
#        'драма,фэнтези', 'документальный,семейный',
#        'фэнтези,драма,приключения', 'ужасы,комедия,фантастика',
#        'драма,мелодрама,музыка', 'фэнтези,драма,семейный',
#        'триллер,мелодрама,драма', 'вестерн,боевик,драма',
#        'мультфильм,короткометражка,комедия', 'триллер,драма,история',
#        'ужасы,фантастика', 'ужасы,мелодрама,комедия',
#        'фэнтези,приключения', 'фантастика,триллер',
#        'ужасы,боевик,фэнтези', 'мультфильм,комедия,детский',
#        'триллер,драма,биография', 'мультфильм,ужасы,фэнтези',
#        'мультфильм,ужасы,фантастика', 'ужасы,боевик,комедия',
#        'драма,биография,спорт', 'мультфильм', 'мелодрама,комедия,драма',
#        'приключения,фантастика,семейный', 'комедия,криминал,детектив',
#        'ужасы,триллер,комедия', 'криминал,комедия,триллер',
#        'семейный,приключения,комедия', 'мультфильм,драма,приключения',
#        'ужасы,драма,детектив', 'драма,приключения,фэнтези',
#        'фантастика,мультфильм,драма', 'драма,триллер,детектив',
#        'драма,история,музыка', 'детский', 'триллер,боевик,криминал',
#        'драма,фантастика', 'комедия,драма,семейный',
#        'боевик,драма,комедия', 'комедия,ужасы',
#        'драма,фантастика,триллер', 'фантастика,драма,триллер',
#        'история,спорт,драма', 'документальный,биография',
#        'биография,история', 'спорт,драма', 'боевик,фэнтези',
#        'мультфильм,фэнтези', 'документальный,комедия,история',
#        'криминал,комедия,боевик', 'фэнтези,приключения,драма',
#        'музыка,концерт', 'триллер,драма,боевик',
#        'комедия,криминал,боевик', 'комедия,фантастика,боевик',
#        'вестерн,приключения,боевик', 'аниме,мультфильм,комедия',
#        'детектив,криминал,триллер', 'мультфильм,комедия,криминал',
#        'комедия,приключения,детектив', 'мелодрама,фантастика,драма',
#        'драма,комедия,семейный', 'приключения,фантастика',
#        'триллер,детектив,ужасы', 'комедия,приключения,фэнтези',
#        'фэнтези,триллер,драма', 'мелодрама,приключения,боевик',
#        'детектив,триллер,криминал', 'фэнтези,семейный,мелодрама',
#        'военный,драма', 'документальный,приключения,семейный',
#        'криминал,комедия,драма', 'комедия,фантастика',
#        'история,биография,драма', 'мелодрама,драма,музыка',
#        'боевик,мелодрама', 'комедия,криминал,триллер',
#        'детектив,триллер,боевик', 'комедия,боевик,криминал',
#        'комедия,вестерн', 'детский,мелодрама,семейный',
#        'короткометражка,мультфильм', 'комедия,фэнтези',
#        'фантастика,драма,ужасы', 'триллер,драма,ужасы',
#        'драма,фэнтези,история', 'комедия,драма,короткометражка',
#        'фэнтези,триллер,приключения', 'семейный',
#        'комедия,криминал,драма', 'комедия,фэнтези,ужасы',
#        'короткометражка,комедия,криминал', 'фантастика',
#        'триллер,ужасы,драма', 'мелодрама,драма,фэнтези',
#        'фантастика,приключения,драма', 'боевик,детектив',
#        'военный,драма,боевик', 'комедия,мелодрама,фэнтези',
#        'вестерн,криминал,триллер', 'драма,история,триллер',
#        'мультфильм,фантастика,боевик', 'детектив,драма,криминал',
#        'приключения,история,драма', 'мультфильм,семейный,детский',
#        'биография,драма,история', 'триллер,криминал,боевик',
#        'история,мелодрама', 'приключения,детский',
#        'музыка,приключения,концерт', 'военный,драма,комедия',
#        'фэнтези,боевик,военный', 'фантастика,детектив,боевик',
#        'мультфильм,фэнтези,история', 'биография,мелодрама,драма',
#        'документальный,биография,спорт', 'фантастика,комедия,детектив',
#        'музыка,концерт,документальный', 'триллер,боевик,приключения',
#        'триллер,драма,комедия', 'детектив,криминал',
#        'мультфильм,приключения,фэнтези', 'мелодрама,приключения',
#        'комедия,музыка', 'мелодрама,комедия,ужасы',
#        'драма,криминал,приключения', 'приключения,детектив,мелодрама',
#        'драма,криминал,фантастика', 'фэнтези,драма,биография',
#        'детектив,фантастика,криминал', 'триллер,драма,фантастика',
#        'ужасы,комедия,боевик', 'мелодрама,история', 'триллер,боевик',
#        'фильм-нуар,триллер,детектив', 'комедия,криминал,приключения',
#        'ужасы,триллер,мелодрама', 'военный,драма,история',
#        'драма,спорт,история', 'документальный,драма,история',
#        'триллер,мелодрама,детектив', 'детский,семейный',
#        'мюзикл,семейный,драма', 'биография,военный,драма',
#        'мультфильм,детский', 'боевик,криминал,драма',
#        'детектив,фэнтези,триллер', 'драма,боевик,приключения',
#        'драма,мелодрама,фэнтези', 'детектив,история,драма',
#        'фэнтези,боевик,ужасы', 'ужасы,фэнтези,мелодрама',
#        'ужасы,приключения', 'боевик,фантастика',
#        'ужасы,мелодрама,детектив', 'фантастика,триллер,приключения',
#        'боевик,приключения,история', 'приключения,боевик,триллер',
#        'детектив,ужасы,криминал', 'семейный,фэнтези', 'мюзикл,мелодрама',
#        'драма,военный,приключения', 'фантастика,драма,приключения',
#        'приключения,семейный,драма', 'история,драма,боевик',
#        'мультфильм,приключения,комедия', 'криминал,драма,комедия',
#        'ужасы,комедия,драма', 'комедия,семейный,приключения',
#        'мюзикл,фэнтези,драма', 'драма,вестерн,боевик',
#        'фантастика,триллер,детектив', 'драма,история,детектив',
#        'короткометражка,биография', 'мультфильм,приключения,фантастика',
#        'комедия,триллер', 'мультфильм,приключения,детектив',
#        'драма,триллер', 'ужасы,триллер,криминал',
#        'документальный,криминал,военный', 'ужасы,фэнтези,драма',
#        'фэнтези,комедия', 'ужасы,фэнтези,комедия', 'комедия,музыка,драма',
#        'мультфильм,приключения,военный', 'мюзикл,фэнтези,комедия',
#        'боевик,фантастика,приключения', 'триллер,ужасы,криминал',
#        'ужасы,фантастика,драма', 'фантастика,приключения,семейный',
#        'короткометражка,музыка', 'мелодрама,детектив,комедия',
#        'документальный,триллер,биография', 'боевик,фантастика,триллер',
#        'спорт,драма,комедия', 'фэнтези,мелодрама,приключения',
#        'триллер,детектив,криминал', 'короткометражка,мелодрама',
#        'мультфильм,семейный,спорт', 'комедия,фэнтези,мелодрама',
#        'драма,спорт,комедия', 'история,драма,мелодрама',
#        'драма,боевик,криминал', 'драма,комедия,триллер',
#        'аниме,мультфильм', 'документальный,ужасы',
#        'мультфильм,короткометражка', 'драма,история,военный',
#        'мультфильм,короткометражка,фэнтези', 'комедия,военный,музыка',
#        'биография,история,драма', 'ужасы,драма,мелодрама',
#        'драма,комедия,детектив', 'комедия,семейный,фантастика',
#        'мультфильм,семейный,комедия', 'история,детектив',
#        'приключения,мелодрама,детектив', 'мюзикл,комедия,мелодрама',
#        'драма,фантастика,ужасы', 'мультфильм,ужасы,комедия',
#        'для взрослых,драма,комедия', 'ужасы,комедия,музыка',
#        'комедия,история,драма', 'семейный,детектив,детский',
#        'короткометражка,драма', 'документальный,новости,драма',
#        'триллер,мелодрама', 'ужасы,драма,вестерн',
#        'мюзикл,фэнтези,семейный', 'вестерн,драма,триллер',
#        'приключения,вестерн,боевик', 'семейный,комедия,музыка',
#        'боевик,драма,вестерн', 'ужасы,драма,триллер',
#        'фантастика,мелодрама', 'комедия,криминал,биография',
#        'семейный,мультфильм,комедия', 'комедия,драма,криминал',
#        'фантастика,боевик,военный', 'приключения,биография,драма',
#        'приключения,триллер,биография', 'криминал,боевик,триллер',
#        'боевик,вестерн,приключения', 'история,драма',
#        'фантастика,фэнтези,комедия', 'мультфильм,детский,комедия',
#        'мелодрама,комедия,триллер', 'документальный,боевик,приключения',
#        'драма,приключения', 'мелодрама,военный,драма', 'триллер,фэнтези',
#        'драма,триллер,биография', 'фэнтези,боевик,семейный',
#        'фантастика,триллер,комедия', 'документальный,фэнтези',
#        'комедия,мультфильм,фантастика', 'криминал,биография,комедия',
#        'биография,спорт,драма', 'приключения,военный',
#        'мультфильм,семейный,драма', 'документальный,фэнтези,драма',
#        'комедия,боевик,фантастика', 'семейный,приключения,военный',
#        'триллер,ужасы,детектив', 'короткометражка',
#        'мелодрама,триллер,история', 'документальный,история',
#        'мультфильм,приключения,детский', 'драма,комедия,мультфильм',
#        'военный,детектив', 'семейный,приключения,документальный',
#        'детский,фэнтези', 'документальный,комедия', 'комедия,биография',
#        'криминал,комедия', 'спорт,мелодрама,криминал',
#        'фантастика,комедия,боевик', 'боевик,приключения,детектив',
#        'детектив,триллер,драма', 'документальный,фантастика',
#        'мелодрама,комедия,семейный', 'мультфильм,мелодрама,комедия',
#        'драма,спорт,семейный', 'фантастика,мелодрама,фэнтези',
#        'мюзикл,комедия,музыка', 'фантастика,триллер,мелодрама',
#        'приключения,комедия,фэнтези', 'фэнтези,боевик,детектив',
#        'фэнтези,боевик,мелодрама', 'комедия,военный',
#        'драма,спорт,боевик', 'мультфильм,боевик,триллер',
#        'мелодрама,семейный', 'фантастика,боевик,детектив',
#        'драма,приключения,история', 'документальный,драма,музыка',
#        'фантастика,триллер,боевик', 'фэнтези,боевик,вестерн',
#        'драма,комедия,мелодрама', 'ужасы,фэнтези,приключения',
#        'триллер,фэнтези,драма', 'мультфильм,мюзикл,мелодрама',
#        'ужасы,триллер,фантастика', 'триллер,мелодрама,комедия',
#        'ужасы,комедия,семейный', 'комедия,приключения,музыка',
#        'документальный,комедия,криминал', 'мелодрама,детектив',
#        'детский,приключения,фантастика', 'короткометражка,боевик,драма',
#        'боевик,комедия,семейный', 'фантастика,боевик,мелодрама',
#        'фэнтези,триллер,мелодрама', 'драма,детектив,история',
#        'боевик,криминал,детектив', 'мультфильм,фэнтези,мелодрама',
#        'мелодрама,драма,боевик', 'драма,вестерн,приключения',
#        'драма,приключения,мелодрама', 'фэнтези,боевик,криминал',
#        'фантастика,комедия,семейный', 'детский,фэнтези,приключения',
#        'ужасы,боевик', 'фантастика,мелодрама,комедия',
#        'семейный,спорт,боевик', 'триллер,биография,драма',
#        'ужасы,драма,комедия', 'мультфильм,фэнтези,триллер', 'мюзикл',
#        'боевик,спорт,драма', 'комедия,приключения,вестерн',
#        'документальный,ужасы,боевик', 'фантастика,боевик,семейный',
#        'военный,история', 'ужасы,боевик,криминал', 'детектив,триллер',
#        'драма,семейный,комедия', 'драма,детектив,приключения',
#        'драма,криминал,история', 'приключения,триллер',
#        'боевик,драма,биография', 'драма,приключения,триллер',
#        'комедия,фэнтези,приключения', 'фантастика,боевик,ужасы',
#        'драма,комедия,фантастика', 'детектив,криминал,драма',
#        'боевик,триллер,фэнтези', 'приключения,детектив,семейный',
#        'ужасы,комедия,криминал', 'мультфильм,биография,драма',
#        'история,боевик,фэнтези', 'детектив,криминал,боевик',
#        'приключения,фэнтези', 'комедия,приключения,спорт',
#        'драма,биография,мюзикл', 'комедия,семейный,фэнтези',
#        'детектив,драма,триллер', 'боевик,приключения,семейный',
#        'биография,спорт,комедия', 'фантастика,приключения,военный',
#        'документальный,драма,биография', 'детектив,приключения,драма',
#        'аниме,мультфильм,приключения', 'семейный,приключения',
#        'ужасы,фэнтези,детектив', 'семейный,документальный',
#        'драма,приключения,семейный', 'приключения,история,военный',
#        'фэнтези,мелодрама', 'фэнтези,триллер,детектив',
#        'документальный,спорт,биография', 'комедия,триллер,драма',
#        'драма,ужасы', 'биография,музыка,драма', 'фэнтези,ужасы',
#        'детектив,мелодрама,фэнтези', 'боевик,военный,история',
#        'биография,драма,криминал', 'триллер,мелодрама,криминал',
#        'семейный,мелодрама', 'биография,драма', 'военный,история,драма',
#        'фантастика,детектив,фэнтези', 'детектив,приключения,триллер',
#        'фантастика,приключения', 'мультфильм,короткометражка,мюзикл',
#        'мультфильм,детский,семейный', 'документальный,драма,комедия',
#        'комедия,приключения,криминал', 'документальный,семейный,музыка',
#        'мелодрама,музыка,драма', 'детектив,фантастика,триллер',
#        'драма,мелодрама,триллер', 'биография,драма,военный',
#        'приключения,фантастика,драма', 'детектив,фильм-нуар,комедия',
#        'документальный,спорт', 'триллер,фантастика,драма',
#        'биография,документальный', 'ужасы,фантастика,мелодрама',
#        'детектив,комедия', 'история,биография,военный',
#        'криминал,мелодрама', 'драма,криминал,вестерн',
#        'мелодрама,семейный,приключения', 'триллер,ужасы,мелодрама',
#        'фэнтези,драма,фильм-нуар', 'детектив,мелодрама',
#        'комедия,драма,биография', 'драма,военный,боевик',
#        'драма,комедия,ужасы', 'фантастика,драма,криминал',
#        'документальный,музыка,биография', 'мультфильм,боевик,приключения',
#        'мультфильм,мелодрама,драма', 'боевик,военный,драма',
#        'фэнтези,семейный,приключения', 'детский,мультфильм,приключения',
#        'семейный,фэнтези,комедия', 'фэнтези,ужасы,триллер',
#        'ужасы,триллер,приключения', 'драма,боевик,история',
#        'фэнтези,комедия,детектив', 'история,приключения',
#        'аниме,мультфильм,короткометражка', 'драма,военный,триллер',
#        'биография,криминал,триллер', 'фантастика,фэнтези,детектив',
#        'вестерн,биография,драма', 'биография,музыка,мюзикл',
#        'драма,история,биография', 'приключения,драма,фантастика',
#        'комедия,фэнтези,криминал', 'биография,спорт,история',
#        'драма,криминал,семейный', 'детектив,боевик,история',
#        'ужасы,комедия,детектив', 'триллер,приключения,драма',
#        'фэнтези,комедия,криминал', 'триллер,криминал,приключения',
#        'комедия,детектив,приключения', 'фэнтези,драма,ужасы',
#        'ужасы,драма,военный', 'реальное ТВ', 'аниме,мультфильм,детектив',
#        'приключения,фэнтези,семейный', 'драма,биография,комедия',
#        'триллер,комедия,ужасы', 'музыка,мелодрама,фэнтези',
#        'мультфильм,история', 'мультфильм,комедия,фантастика',
#        'биография,криминал,драма', 'комедия,мелодрама,фантастика',
#        'криминал,боевик,комедия', 'история,криминал',
#        'детектив,комедия,драма', 'триллер,фантастика,боевик',
#        'криминал,боевик', 'комедия,драма,военный',
#        'драма,триллер,криминал', 'мультфильм,мелодрама,приключения',
#        'фантастика,фэнтези,триллер', 'короткометражка,драма,триллер',
#        'военный,боевик,история', 'боевик,драма,триллер',
#        'документальный,военный,драма', 'драма,криминал,фильм-нуар',
#        'мультфильм,детский,приключения', 'мелодрама,история,драма'],
#       dtype=object)

# %%
data['genres'].value_counts()
# Out:
# драма                             476
# комедия                           351
# мелодрама,комедия                 222
# драма,мелодрама,комедия           189
# драма,мелодрама                   183
#                                  ...
# триллер,фантастика,боевик           1
# драма,криминал,фантастика           1
# документальный,драма,биография      1
# ужасы,фантастика,мелодрама          1
# боевик,военный,драма                1
# Name: genres, Length: 741, dtype: int64

# %% [markdown]
# В данных столбца genres -жанр фильма было пропущено 957 или 12.8 % значений. Можно предположить, имел место человеческий фактор - не все данные заполнялись, либо данная информация была необязательна для заполнения, возможно, технический сбой.
#
# Пропущенные значения жанра фильма не заполнялись, так как нет возможности заполнить корректными значениями.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# С обработкой пропусков все хорошо! Действительно, большую часть можно не заполнять или использовать значение "unknown"
# </div>

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не выявлено.
#
# Проверим на неявные дубликаты столбец title -название фильма.

# %%
data['title'].value_counts()
# Out:
# День святого Валентина_                               5
# Начало_                                               4
# Рапунцель: Запутанная история                         4
# Дорога /По новелле Кормака МкКарфи/                   4
# Белая мгла /По комиксу Грега Рукка и Стива Либера/    4
#                                                      ..
# Приходит дракон                                       1
# Звуки шума                                            1
# Горные огни                                           1
# Президент Линкольн: Охотник на вампиров               1
# Нико                                                  1
# Name: title, Length: 6746, dtype: int64

# %% [markdown]
# Посмотрим информацию по нескольким фильмам, где неявные дубликаты выявлены в названии фильма -title.

# %%
data[(data.title=='День святого Валентина_')]
# Out:
#                         title  pu_number           show_start_date  \
# 3902  День святого Валентина_  221083810 2010-07-15 12:00:00+00:00
# 3991  День святого Валентина_  221068010 2010-05-14 12:00:00+00:00
# 4070  День святого Валентина_  121002210 2010-02-03 12:00:00+00:00
# 4196  День святого Валентина_  221136210 2010-11-30 12:00:00+00:00
# 5070  День святого Валентина_  221066410 2010-06-01 12:00:00+00:00
#
#                 type                                        film_studio  \
# 3902  Художественный  Уорнер Бразерс, Нью Лайн Синема, Уэйн Райс, Ка...
# 3991  Художественный  Уорнер Бразерс, Нью Лайн Синема, Уэйн Райс, Ка...
# 4070  Художественный  Уорнер Бразерс, Нью Лайн Синема, Уэйн Райс, Ка...
# 4196  Художественный  Уорнер Бразерс, Нью Лайн Синема, Уэйн Райс, Ка...
# 5070  Художественный  Уорнер Бразерс, Нью Лайн Синема, Уэйн Райс, Ка...
#
#      production_country       director         producer  \
# 3902                США  Гарри Маршалл  Сэмюэл Дж.Браун
# 3991                США  Гарри Маршалл  Сэмюэл Дж.Браун
# 4070                США  Гарри Маршалл  Сэмюэл Дж.Браун
# 4196                США  Гарри Маршалл  Сэмюэл Дж.Браун
# 5070                США  Гарри Маршалл  Сэмюэл Дж.Браун
#
#                       age_restriction  refundable_support  \
# 3902  «16+» - для детей старше 16 лет                 NaN
# 3991  «16+» - для детей старше 16 лет                 NaN
# 4070  «16+» - для детей старше 16 лет                 NaN
# 4196  «16+» - для детей старше 16 лет                 NaN
# 5070  «16+» - для детей старше 16 лет                 NaN
#
#       non_refundable_support  budget financing_source  ratings  \
# 3902                     NaN     NaN              NaN     6.70
# 3991                     NaN     NaN              NaN     6.70
# 4070                     NaN     NaN              NaN     6.70
# 4196                     NaN     NaN              NaN     6.70
# 5070                     NaN     NaN              NaN     6.70
#
#                  genres  box_office
# 3902  мелодрама,комедия         NaN
# 3991  мелодрама,комедия         NaN
# 4070  мелодрама,комедия         NaN
# 4196  мелодрама,комедия         NaN
# 5070  мелодрама,комедия         NaN

# %%
data[(data.title=='Знакомство с Факерами 2.')]
# Out:
#                          title  pu_number           show_start_date  \
# 4129  Знакомство с Факерами 2.  121021710 2010-11-25 12:00:00+00:00
# 4886  Знакомство с Факерами 2.  221034211 2011-04-05 12:00:00+00:00
# 4989  Знакомство с Факерами 2.  221049411 2011-03-30 12:00:00+00:00
# 5390  Знакомство с Факерами 2.  221117511 2011-11-15 12:00:00+00:00
#
#                 type                                        film_studio  \
# 4129  Художественный  Парамаунт Пикчерз, Юниверсал Пикчерз, ДУ Студи...
# 4886  Художественный  Парамаунт Пикчерз, Юниверсал Пикчерз, ДУ Студи...
# 4989  Художественный  Парамаунт Пикчерз, Юниверсал Пикчерз, ДУ Студи...
# 5390  Художественный  Парамаунт Пикчерз, Юниверсал Пикчерз, ДУ Студи...
#
#      production_country  director  \
# 4129                США  Пол Вайц
# 4886                США  Пол Вайц
# 4989                США  Пол Вайц
# 5390                США  Пол Вайц
#
#                                                producer  \
# 4129  Роберт Де Ниро, Джон Гамбург, Джей Роач, Джейн...
# 4886  Роберт Де Ниро, Джон Гамбург, Джей Роач, Джейн...
# 4989  Роберт Де Ниро, Джон Гамбург, Джей Роач, Джейн...
# 5390  Роберт Де Ниро, Джон Гамбург, Джей Роач, Джейн...
#
#                       age_restriction  refundable_support  \
# 4129  «16+» - для детей старше 16 лет                 NaN
# 4886  «16+» - для детей старше 16 лет                 NaN
# 4989  «16+» - для детей старше 16 лет                 NaN
# 5390  «16+» - для детей старше 16 лет                 NaN
#
#       non_refundable_support  budget financing_source  ratings  \
# 4129                     NaN     NaN              NaN     6.20
# 4886                     NaN     NaN              NaN     6.20
# 4989                     NaN     NaN              NaN     6.20
# 5390                     NaN     NaN              NaN     6.20
#
#                  genres  box_office
# 4129  мелодрама,комедия         NaN
# 4886  мелодрама,комедия         NaN
# 4989  мелодрама,комедия         NaN
# 5390  мелодрама,комедия         NaN

# %%
data[(data.title=='Дорога /По новелле Кормака МкКарфи/')]
# Out:
#                                     title  pu_number  \
# 356   Дорога /По новелле Кормака МкКарфи/  221010415
# 4003  Дорога /По новелле Кормака МкКарфи/  121009410
# 4582  Дорога /По новелле Кормака МкКарфи/  221157110
# 4735  Дорога /По новелле Кормака МкКарфи/  221082210
#
#                show_start_date            type  \
# 356  2015-04-03 12:00:00+00:00  Художественный
# 4003 2010-05-26 12:00:00+00:00  Художественный
# 4582 2010-12-17 12:00:00+00:00  Художественный
# 4735 2010-10-14 12:00:00+00:00  Художественный
#
#                                      film_studio production_country  \
# 356   Дименшн Филмс, Род Ребел, Чокстоун Пикчерз                США
# 4003  Дименшн Филмс, Род Ребел, Чокстоун Пикчерз                США
# 4582  Дименшн Филмс, Род Ребел, Чокстоун Пикчерз                США
# 4735  Дименшн Филмс, Род Ребел, Чокстоун Пикчерз                США
#
#            director         producer              age_restriction  \
# 356   Джон Хиллкоут  Паула Мэй Шварц  «18+» - запрещено для детей
# 4003  Джон Хиллкоут  Паула Мэй Шварц  «18+» - запрещено для детей
# 4582  Джон Хиллкоут  Паула Мэй Шварц  «18+» - запрещено для детей
# 4735  Джон Хиллкоут  Паула Мэй Шварц  «18+» - запрещено для детей
#
#       refundable_support  non_refundable_support  budget financing_source  \
# 356                  NaN                     NaN     NaN              NaN
# 4003                 NaN                     NaN     NaN              NaN
# 4582                 NaN                     NaN     NaN              NaN
# 4735                 NaN                     NaN     NaN              NaN
#
#       ratings genres  box_office
# 356      7.20  драма         NaN
# 4003     7.20  драма         NaN
# 4582     7.20  драма         NaN
# 4735     7.20  драма         NaN

# %%
data[data['title'].isin(data['title'].value_counts()[data['title'].value_counts()>1].index)]
# Out:
#                                                   title  pu_number  \
# 2                                          Особо опасен  221038416
# 3                                          Особо опасен  221026916
# 4                                          Особо опасен  221030815
# 12    Малышка на миллион /По мотивам рассказов Ф.Х.Т...  221011415
# 26                                      Оружейный барон  221012515
# ...                                                 ...        ...
# 7369                                          Невиновен  111019319
# 7416                             Отель "Гранд Будапешт"  121035119
# 7438                                              Зверь  121035919
# 7450                                      В тихом омуте  121036919
# 7474                                          Вторжение  111022519
#
#                show_start_date             type  \
# 2    2016-10-10 12:00:00+00:00   Художественный
# 3    2016-06-10 12:00:00+00:00   Художественный
# 4    2015-07-29 12:00:00+00:00   Художественный
# 12   2015-04-03 12:00:00+00:00   Художественный
# 26   2015-04-03 12:00:00+00:00   Художественный
# ...                        ...              ...
# 7369 2019-11-07 12:00:00+00:00   Художественный
# 7416 2019-12-13 12:00:00+00:00   Художественный
# 7438 2019-12-05 12:00:00+00:00   Художественный
# 7450 2019-12-09 12:00:00+00:00   Художественный
# 7474 2019-12-23 12:00:00+00:00   Художественный
#
#                                             film_studio  \
# 2     Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 3     Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 4     Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 12    Уорнер Бразерс, Лейкшор Интертейнмент, Малпасо...
# 26    Вэ И Пэ Медиенфондс 3, Асендант Пикчерз, Сатур...
# ...                                                 ...
# 7369                                  ООО "Кавказфильм"
# 7416  Американ Эмпирикал, Индиан Пэинтбраш, Скотт Ру...
# 7438                                     Студио энд Нью
# 7450  Хэд Гир Филмз, Крео Филмз, Локал Хироу, Метрол...
# 7474       ООО "Арт Пикчерс Студия", ООО "Водород 2011"
#
#           production_country           director  \
# 2                        США  Тимур Бекмамбетов
# 3                        США  Тимур Бекмамбетов
# 4                        США  Тимур Бекмамбетов
# 12                       США       Клинт Иствуд
# 26    США - Франция - Турция       Эндрю Никкол
# ...                      ...                ...
# 7369                  Россия          А.Емкужев
# 7416           Германия, США       Уэс Андерсен
# 7438             Южная Корея         Ли Джон-хо
# 7450                     США       Адам Рэндолл
# 7474                  Россия        Ф.Бондарчук
#
#                                                producer  \
# 2     Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3     Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4     Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 12    Клинт Иствуд, Том Розенберг, Альберт С.Рудди, ...
# 26    Норман Голуайтли, Энди Грош, Николас Кейдж, Эн...
# ...                                                 ...
# 7369  А.Емкужев, А.Хуажева, ООО "Корпорация Русская ...
# 7416         Уэс Андерсон, Джереми Доусон, Стивен Рейлс
# 7438               Чан Гён-ик, Чон Джи-хун, Пэк Кён сук
# 7450                                        Мэтт Уолдек
# 7474  Ф.Бондарчук, М.Врубель, А.Андрющенко, Д.Рудовский
#
#                       age_restriction  refundable_support  \
# 2         «18+» - запрещено для детей                 NaN
# 3         «18+» - запрещено для детей                 NaN
# 4         «18+» - запрещено для детей                 NaN
# 12    «16+» - для детей старше 16 лет                 NaN
# 26        «18+» - запрещено для детей                 NaN
# ...                               ...                 ...
# 7369  «16+» - для детей старше 16 лет                 NaN
# 7416  «16+» - для детей старше 16 лет                 NaN
# 7438      «18+» - запрещено для детей                 NaN
# 7450      «18+» - запрещено для детей                 NaN
# 7474  «12+» - для детей старше 12 лет      100,000,000.00
#
#       non_refundable_support         budget financing_source  ratings  \
# 2                        NaN            NaN              NaN     6.80
# 3                        NaN            NaN              NaN     6.80
# 4                        NaN            NaN              NaN     6.80
# 12                       NaN            NaN              NaN     8.10
# 26                       NaN            NaN              NaN     7.70
# ...                      ...            ...              ...      ...
# 7369                     NaN            NaN              NaN     7.50
# 7416                     NaN            NaN              NaN     7.90
# 7438                     NaN            NaN              NaN     6.50
# 7450                     NaN            NaN              NaN     6.80
# 7474          400,000,000.00 944,000,000.00        Фонд кино     5.70
#
#                             genres  box_office
# 2        фантастика,боевик,триллер         NaN
# 3        фантастика,боевик,триллер         NaN
# 4        фантастика,боевик,триллер         NaN
# 12                     драма,спорт         NaN
# 26           боевик,драма,криминал         NaN
# ...                            ...         ...
# 7369     триллер,детектив,криминал         NaN
# 7416  комедия,приключения,детектив         NaN
# 7438                 триллер,драма  175,003.51
# 7450     триллер,криминал,детектив         NaN
# 7474             фантастика,боевик         NaN
#
# [1270 rows x 16 columns]

# %%
data[data['title'].isin(data['title'].value_counts()[data['title'].value_counts()>1].index)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1270 entries, 2 to 7474
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   1270 non-null   object
#  1   pu_number               1270 non-null   object
#  2   show_start_date         1270 non-null   datetime64[ns, UTC]
#  3   type                    1270 non-null   object
#  4   film_studio             1270 non-null   object
#  5   production_country      1270 non-null   object
#  6   director                1270 non-null   object
#  7   producer                1270 non-null   object
#  8   age_restriction         1270 non-null   object
#  9   refundable_support      5 non-null      float64
#  10  non_refundable_support  5 non-null      float64
#  11  budget                  5 non-null      float64
#  12  financing_source        5 non-null      object
#  13  ratings                 1254 non-null   float64
#  14  genres                  1254 non-null   object
#  15  box_office              228 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(5), object(10)
# memory usage: 168.7+ KB

# %% [markdown]
# Всего 1270 строк, где название фильма встречается более одного раза. В то же время во всех случаях номер прокатного удостоверения и дата премьеры фильма - это разные значения. Один фильм может иметь несколько прокатных удостоверений в случае, если они выдавались в разнае сроки и для разных прокатных целей. Также фильм мог поменять правообладателя или даже быть немного изменендля каких-либо творческих или коммерческих целей - с документальной точки зрения это требует выдачи новой "прокатки".
#
# Данные столбца оставляю без изменений.

# %% [markdown]
# Проверим на неявные дубликаты столбец pu_number -номер прокатного удостоверения.

# %%
data['pu_number'].unique()
# Out:
# array(['221048915', '111013716', '221038416', ..., '124010819',
#        '124010619', '124010719'], dtype=object)

# %%
data['pu_number'].value_counts()
# Out:
# 221054410    2
# 221154310    2
# 111019718    1
# 121019217    1
# 121007412    1
#             ..
# 111015314    1
# 111001414    1
# 111009916    1
# 221176010    1
# 121026218    1
# Name: pu_number, Length: 7457, dtype: int64

# %%
data[data['pu_number'].isin(data['pu_number'].value_counts()[data['pu_number'].value_counts()>1].index)]
# Out:
#                                                   title  pu_number  \
# 4638                   Как жениться и остаться холостым  221154310
# 4639  Иоанна - женщина на папском престоле /По роман...  221154310
# 5067                                    Анализируй это!  221054410
# 5068                                     Анализируй то!  221054410
#
#                show_start_date            type  \
# 4638 2010-12-17 12:00:00+00:00  Художественный
# 4639 2010-12-17 12:00:00+00:00  Художественный
# 5067 2010-05-25 12:00:00+00:00  Художественный
# 5068 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4638  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4639   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
# 5067          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 5068  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#                                 production_country        director  \
# 4638                                       Франция    Эрик Лартиго
# 4639  Германия - Великобритания - Италия - Испания  Зенке Вортманн
# 5067                                 США-Австралия   ХЭрольд Рэмис
# 5068                                           США  Гарольд Реймис
#
#                                         producer  \
# 4638                     Амандин Било, Алан Шаба
# 4639  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
# 5067             Джейн Розенталь, Пола Уейнстейн
# 5068             Джейн Розенталь, Паул Уэйнстейн
#
#                       age_restriction  refundable_support  \
# 4638  «16+» - для детей старше 16 лет                 NaN
# 4639  «16+» - для детей старше 16 лет                 NaN
# 5067  «16+» - для детей старше 16 лет                 NaN
# 5068  «12+» - для детей старше 12 лет                 NaN
#
#       non_refundable_support  budget financing_source  ratings  \
# 4638                     NaN     NaN              NaN     7.00
# 4639                     NaN     NaN              NaN     7.60
# 5067                     NaN     NaN              NaN     7.40
# 5068                     NaN     NaN              NaN     6.80
#
#                        genres  box_office
# 4638        мелодрама,комедия         NaN
# 4639  драма,мелодрама,история         NaN
# 5067         комедия,криминал         NaN
# 5068         комедия,криминал         NaN

# %% [markdown]
# Выявлено 2 повторяющиеся в столбце номера прокатного удостоверения -221154310 и 221054410. При этом фильм с номером 221054410 - "Анализируй это!" и "Анализируй то!", скорее всего один и тот же фильм, который дважды внесен в базу данных по ошибке, так как основная информация дублируется -это неявный дубликат. Фильм с номером прокатного удостоверения 221154310 - "Как жениться и остаться холостым" и "Иоанна - женщина на папском престоле /По роман...", скорее всего два разных фильма, так как информация в названиии фильма, студии-производителе, директоре, режиссере, стране-производителе различается. Скорее всего здесь здесь допущена ошибка при внесении номера прокатного удостоверения или произошла техническая ошибка.
#
# Оба повторяющихся значения с номером прокатного удостоверения удаляю, так как номер прокатного удостоверения - это уникальные значения, которые не должны повторяться.

# %%
data.drop(data.index[data['title']=='Как жениться и остаться холостым'],inplace=True)
data.drop(data.index[data['title']=='Анализируй это!'],inplace=True)

# %% [markdown]
# Проверим.

# %%
data[data['pu_number'].isin(data['pu_number'].value_counts()[data['pu_number'].value_counts()>1].index)]
# Out:
# Empty DataFrame
# Columns: [title, pu_number, show_start_date, type, film_studio, production_country, director, producer, age_restriction, refundable_support, non_refundable_support, budget, financing_source, ratings, genres, box_office]
# Index: []

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера ❗</b>
#
# Еще уникальные значения должны быть в pu_number, давай проверим это
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Проверила. Действительно нашлось два дубликата, удалила их.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера 2 ⚠️</b>
#
# А вдруг у нас несколько фильмов с названием 'Как жениться и остаться холостым' и 'Анализируй это!'?
#
# Если мы решили удалить эти строки, то лучше использовать метод drop_duplicates или удалять по индексу строки.
# </div>

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# Рассмотрим столбец type - тип фильма, скорректируем проблемные значения.

# %%
data['type'].unique()
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', ' Художественный', ' Анимационный',
#        'Музыкально-развлекательный'], dtype=object)

# %%
data['type']=[_.replace(' ','') for _ in data['type']]

# %%
data['type'].unique()
# Out:
# array(['Художественный', 'Анимационный', 'Прочие', 'Документальный',
#        'Научно-популярный', 'Музыкально-развлекательный'], dtype=object)

# %%
data['type'].value_counts()
# Out:
# Художественный                5894
# Анимационный                   829
# Прочие                         401
# Документальный                 280
# Научно-популярный               50
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %%
sns.histplot(data['type'], kde=False, bins=30)
plt.xlim(0,6)
plt.title('Тип фильма')
plt.xlabel('Тип фильма')
plt.xticks(rotation=45)
plt.ylabel('Количество фильмов')
plt.show()

# %% [markdown]
# В столбцах genres - жанр фильма, film_studio - студия-производитель, director - режиссёр, producer - продюсер, production_country - страна-производитель - многие параметры представлены списком, где через запятую перечислены несколько значений, что затрудняет их группировку и исследование.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Ты абсолютно права
# </div>

# %%
data['genres'].value_counts()
# Out:
# драма                             476
# комедия                           351
# мелодрама,комедия                 220
# драма,мелодрама,комедия           189
# драма,мелодрама                   183
#                                  ...
# триллер,фантастика,боевик           1
# драма,криминал,фантастика           1
# документальный,драма,биография      1
# ужасы,фантастика,мелодрама          1
# боевик,военный,драма                1
# Name: genres, Length: 741, dtype: int64

# %%
len(data['genres'].unique())
# Out:
# 742

# %%
data['film_studio'].value_counts()
# Out:
# Киностудия "Мосфильм"                                                                                              341
# ООО "Мульт в кино"                                                                                                  57
# Анимаккорд Лтд                                                                                                      23
# ООО "Мульт в кино"                                                                                                  18
# ФГУП "ТПО "Киностудия "Союзмультфильм"                                                                              16
#                                                                                                                   ...
# Базелевс Продакшн, Итака Филмз, Лимон Студиос, Ла Бода Продакшнз                                                     1
# Дентсю, Фьюджи Телевижн Нетворк Интертейнмент, Хаммер энд Тонгс,  Иллюминейшн Интертейнмент, Юниверсал Пикчерз       1
# Хуай Бразерс Пикчерз, Лэйкшор Интертейнмент, ЭсТиЭкс Интертейнмент, Вертиго Интертейнмент                            1
# Ассочиак, 8 Продакшен, Талея фильм, 11 Марцо фильм, СиЭсСи Продакшен, Редиджитал Студио, Маэстро Продакшен           1
# Блок Интертейнмент, Роберт Симондс Компани, Эс Ти Икс Интертейнмент                                                  1
# Name: film_studio, Length: 5483, dtype: int64

# %%
len(data['film_studio'].unique())
# Out:
# 5483

# %%
data['director'].value_counts()
# Out:
# О.Семёнова                47
# Стивен Содерберг          17
# Д.Червяцов                17
# Ридли Скотт               16
# Тиль Швайгер              14
#                           ..
# Срджан Драгоевич           1
# Дэнни Панг, Оксид Панг     1
# М.Катушкин                 1
# Ник Пойнц                  1
# Е.Резников                 1
# Name: director, Length: 4794, dtype: int64

# %%
len(data['director'].unique())
# Out:
# 4794

# %%
data['producer'].value_counts()
# Out:
# unknown                                                                          564
# П.Смирнов                                                                         67
# Олег Кузовков, Дмитрий Ловейко, Марина Ратина                                     28
# С.Сельянов                                                                        18
# Д.Ловейко, О.Кузовков                                                             17
#                                                                                 ...
# ЗАО "Киновидеообъединение "Крупный план"                                           1
# Майк Бек, Альваро Бакеро Бенедетти, Алекс Дрэйпер, Ричард В.Кинг, Энди Миттон      1
# Ави Арад                                                                           1
# Келли Броад, Воган Сивелл                                                          1
# Дон Кемпф, Анди Уд                                                                 1
# Name: producer, Length: 5328, dtype: int64

# %%
len(data['producer'].unique())
# Out:
# 5328

# %%
data['production_country'].value_counts()
# Out:
# США                            2171
# Россия                         1802
# СССР                            347
# Франция                         299
# Великобритания                  253
#                                ...
# США-ФРГ-Россия                    1
# Великобритания-Франция            1
# Франция - Бразилия - Италия       1
# Иран                              1
# Франция-Германия-Италия           1
# Name: production_country, Length: 950, dtype: int64

# %%
len(data['production_country'].unique())
# Out:
# 950

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['budget'].sum()
# Out:
# 42240265939.0

# %%
data['refundable_support'].sum()
# Out:
# 3939000000.0

# %%
data['non_refundable_support'].sum()
# Out:
# 16261688312.0

# %% [markdown]
# Для более удобного формата переведем рублевые значения в млн.руб.

# %%
data['budget_mln']=round(data['budget']/1000000,2)

# %%
data['budget_mln'].describe()
# Out:
# count     332.00
# mean      127.23
# std       188.59
# min         0.00
# 25%        42.00
# 50%        68.65
# 75%       141.98
# max     2,305.07
# Name: budget_mln, dtype: float64

# %%
data['budget_mln'].sum()
# Out:
# 42240.24

# %%
sns.histplot(data['budget_mln'], kde=False, bins=30)
plt.xlim(0,400)
plt.title('Бюджет фильма')
plt.xlabel('Бюджет фильма')
plt.xticks(rotation=45)
plt.ylabel('Частота')
plt.show()

# %%
data['refundable_support_mln']=round(data['refundable_support']/1000000,2)

# %%
data['refundable_support_mln'].sum()
# Out:
# 3939.0

# %%
data['refundable_support_mln'].describe()
# Out:
# count   332.00
# mean     11.86
# std      24.92
# min       0.00
# 25%       0.00
# 50%       0.00
# 75%      15.00
# max     180.00
# Name: refundable_support_mln, dtype: float64

# %%
sns.histplot(data['refundable_support_mln'], kde=False, bins=30)
plt.xlim(0,40)
plt.title('Объём возвратных средств государственной поддержки')
plt.xlabel('Объём возвратных средств')
plt.xticks(rotation=45)
plt.ylabel('Частота')
plt.show()

# %%
data['non_refundable_support_mln']=round(data['non_refundable_support']/1000000,2)

# %%
data['non_refundable_support_mln'].describe()
# Out:
# count   332.00
# mean     48.98
# std      59.98
# min       0.00
# 25%      25.00
# 50%      30.00
# 75%      40.38
# max     400.00
# Name: non_refundable_support_mln, dtype: float64

# %%
data['non_refundable_support_mln'].sum()
# Out:
# 16261.680000000002

# %%
sns.histplot(data['non_refundable_support_mln'], kde=False, bins=30)
plt.xlim(0,100)
plt.title('Объём невозвратных средств государственной поддержки')
plt.xlabel('Объём невозвратных средств')
plt.xticks(rotation=45)
plt.ylabel('Частота')
plt.show()

# %%
data['box_office_mln']=round(data['box_office']/1000000,2)

# %%
data['box_office_mln'].describe()
# Out:
# count   3,155.00
# mean       76.55
# std       240.46
# min         0.00
# 25%         0.09
# 50%         2.34
# 75%        24.00
# max     3,073.57
# Name: box_office_mln, dtype: float64

# %%
data['box_office_mln'].sum()
# Out:
# 241518.99

# %%
sns.histplot(data['box_office_mln'], kde=False, bins=30)
plt.xlim(0,500)
plt.title('Сборы, млн.руб.')
plt.xlabel('Сборы')
plt.xticks(rotation=45)
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Посмотрим данные столбцов non_refundable_support_mln, budget_mln, refundable_support_mln.

# %%
movies_data=data[['budget_mln','non_refundable_support_mln', 'refundable_support_mln']]
movies_data[movies_data.notna().any(axis=1)]
# Out:
#       budget_mln  non_refundable_support_mln  refundable_support_mln
# 1281       79.41                       26.50                    0.00
# 1448       37.14                       26.00                    0.00
# 1498      176.02                      107.85                    0.00
# 1524       40.57                       28.00                    0.00
# 1792       40.02                       25.00                    0.00
# ...          ...                         ...                     ...
# 7464      980.00                      400.00                  100.00
# 7466      190.00                        0.00                  100.00
# 7474      944.00                      400.00                  100.00
# 7476       46.15                       30.00                    0.00
# 7478      150.15                       60.00                   40.00
#
# [332 rows x 3 columns]

# %% [markdown]
# Часть значений в столбце budget- общий бюджет фильма равен 0, хотя в стобцах refundable_support_mln - объём возвратных средств государственной поддержки и non_refundable_support_mln - объём невозвратных средств государственной поддержки есть значения.
# В этом случае значения 0 в столбце budget -общий бюджет фильма - это ошибочной значение. Причиной мог послужить технический сбой. Выведем срез таких значений - их 17.

# %%
data[(data.budget_mln==0)&((data.refundable_support_mln >0)|(data.non_refundable_support_mln>0))]
# Out:
#                        title  pu_number           show_start_date  \
# 2053                     14+  111023614 2014-12-19 12:00:00+00:00
# 2058               Дуxless 2  111000415 2015-01-26 12:00:00+00:00
# 2472             Воин (2015)  111017315 2015-09-28 12:00:00+00:00
# 2532                 Бармен.  111009615 2015-05-26 12:00:00+00:00
# 2615     Савва. Сердце воина  114001715 2015-07-21 12:00:00+00:00
# 2684          Тряпичный союз  111010215 2015-06-08 12:00:00+00:00
# 2788      Срочно выйду замуж  111017115 2015-09-30 12:00:00+00:00
# 2874       Помню - не помню!  111004916 2016-03-01 12:00:00+00:00
# 3047  Любовь с ограничениями  111008216 2016-04-29 12:00:00+00:00
# 3565       Притяжение (2016)  111018116 2016-12-16 12:00:00+00:00
# 3675                Чудо-юдо  114001817 2017-06-27 12:00:00+00:00
# 3739                    Мифы  111004317 2017-06-07 12:00:00+00:00
# 5673                   Селфи  111012117 2018-02-01 12:00:00+00:00
# 5806              Два хвоста  114001018 2018-05-31 12:00:00+00:00
# 6008      Принцесса и дракон  114003018 2018-08-23 12:00:00+00:00
# 6323                Баба Яга  114006518 2018-11-08 12:00:00+00:00
# 6823     Большое путешествие  114002419 2019-04-20 12:00:00+00:00
#
#                 type                                        film_studio  \
# 2053  Художественный                         ООО Киностудия  "Сентябрь"
# 2058  Художественный  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"
# 2472  Художественный   ООО "Форпост Продакшн", ООО "Арт Пикчерс Студия"
# 2532  Художественный          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"
# 2615    Анимационный   ООО "Глюкоза Продакшн", ООО "Арт Пикчерс Студия"
# 2684  Художественный                      ООО "Кинокомпания "КОКТЕБЕЛЬ"
# 2788  Художественный          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"
# 2874  Художественный                                    ООО "КиноФирма"
# 3047  Художественный          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"
# 3565  Художественный      ООО "Водород 2011",  ООО "Арт Пикчерс Студия"
# 3675    Анимационный                                    ООО "КиноФирма"
# 3739  Художественный           ООО "ХАЙПФИЛМ", ООО "Арт Пикчерс Студия"
# 5673  Художественный  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"
# 5806    Анимационный                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6008    Анимационный                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6323    Анимационный                           ООО "Арт Пикчерс Студия"
# 6823    Анимационный                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
#
#      production_country                        director  \
# 2053             Россия                        А.Зайцев
# 2058             Россия                      Р.Прыгунов
# 2472             Россия                     А.Андрианов
# 2532             Россия                    Д.Штурманова
# 2615             Россия                        М.Фадеев
# 2684             Россия                     М.Местецкий
# 2788             Россия                       С Чекалов
# 2874             Россия                     В.Ровенский
# 3047             Россия                         Д.Тюрин
# 3565             Россия                     Ф.Бондарчук
# 3675             Россия                       А.Лукичев
# 3739             Россия                    А.Молочников
# 5673             Россия                      Н.Хомерики
# 5806             Россия  В.Ровенский, Н.Лопато, В.Азеев
# 6008             Россия                      М.Нефедова
# 6323             Россия                         В.Саков
# 6823             Россия           Н.Лопато, В.Ровенский
#
#                                                producer  \
# 2053                                О.Гранина, А.Зайцев
# 2058                 П.Ануров, Ф.Бондарчук, Д.Рудовский
# 2472                           ООО "Арт Пикчерс Студия"
# 2532                                        Т.Вайнштейн
# 2615                                         А.Чистяков
# 2684                              Р.Борисевич, А.Кушаев
# 2788              Ф.Бондарчук, Т.Вайнштейн, Д.Рудовский
# 2874                                    ООО "КиноФирма"
# 3047              Ф.Бондарчук, Т.Вайнштейн, Д.Рудовский
# 3565                           ООО "Арт Пикчерс Студия"
# 3675                                    ООО "КиноФирма"
# 3739  Ф.Бондарчук, Д.Рудовский, И.Стюарт, М.Османн, ...
# 5673                 П.Ануров, Ф.Бондарчук, Д.Рудовский
# 5806                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6008                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
# 6323  ООО "Арт Пикчерс Студия", ООО "КРИЭЙТИВ АНИМЭЙ...
# 6823                          ООО "ЛИЦЕНЗИОННЫЕ БРЕНДЫ"
#
#                       age_restriction  refundable_support  \
# 2053  «16+» - для детей старше 16 лет                0.00
# 2058  «16+» - для детей старше 16 лет                0.00
# 2472  «12+» - для детей старше 12 лет       10,000,000.00
# 2532  «16+» - для детей старше 16 лет       20,000,000.00
# 2615    «6+» - для детей старше 6 лет       60,000,000.00
# 2684      «18+» - запрещено для детей                0.00
# 2788  «16+» - для детей старше 16 лет                0.00
# 2874  «12+» - для детей старше 12 лет                0.00
# 3047  «16+» - для детей старше 16 лет       19,000,000.00
# 3565  «12+» - для детей старше 12 лет                0.00
# 3675    «6+» - для детей старше 6 лет       20,000,000.00
# 3739  «16+» - для детей старше 16 лет       25,000,000.00
# 5673  «16+» - для детей старше 16 лет       20,000,000.00
# 5806    «6+» - для детей старше 6 лет       10,000,000.00
# 6008    «6+» - для детей старше 6 лет       40,000,000.00
# 6323    «6+» - для детей старше 6 лет                0.00
# 6823    «6+» - для детей старше 6 лет       60,000,000.00
#
#       non_refundable_support  budget                  financing_source  \
# 2053           23,000,000.00    0.00  Министерство культуры, Фонд кино
# 2058           75,000,000.00    0.00                         Фонд кино
# 2472           70,000,000.00    0.00                         Фонд кино
# 2532                    0.00    0.00                         Фонд кино
# 2615          100,000,000.00    0.00                         Фонд кино
# 2684           59,000,000.00    0.00                         Фонд кино
# 2788           35,000,000.00    0.00                         Фонд кино
# 2874            6,000,000.00    0.00             Министерство культуры
# 3047           51,000,000.00    0.00                         Фонд кино
# 3565          250,000,000.00    0.00                         Фонд кино
# 3675           20,000,000.00    0.00                         Фонд кино
# 3739           20,000,000.00    0.00                         Фонд кино
# 5673           40,000,000.00    0.00                         Фонд кино
# 5806           60,000,000.00    0.00                         Фонд кино
# 6008           40,000,000.00    0.00                         Фонд кино
# 6323          138,969,465.00    0.00                         Фонд кино
# 6823          120,000,000.00    0.00                         Фонд кино
#
#       ratings                          genres       box_office  budget_mln  \
# 2053     6.60                       мелодрама    10,234,016.10        0.00
# 2058     6.60                           драма   446,163,511.00        0.00
# 2472     7.80           боевик,драма,криминал   196,572,438.40        0.00
# 2532     6.20                 комедия,фэнтези    67,418,974.80        0.00
# 2615     4.60  мультфильм,приключения,фэнтези   184,487,551.40        0.00
# 2684     6.30                   комедия,драма     1,957,738.51        0.00
# 2788     5.10               комедия,мелодрама    72,937,783.20        0.00
# 2874     4.30                         комедия    15,362,931.43        0.00
# 3047     6.30               комедия,мелодрама    70,299,052.00        0.00
# 3565     5.60                      фантастика 1,038,321,489.00        0.00
# 3675     5.20     мультфильм,фэнтези,семейный    55,108,014.76        0.00
# 3739     4.80                         комедия    50,451,949.00        0.00
# 5673     5.80                   триллер,драма   225,196,400.03        0.00
# 5806     5.00              мультфильм,детский   106,514,301.03        0.00
# 6008     5.20      мультфильм,фэнтези,детский    83,366,328.66        0.00
# 6323      NaN                             NaN     1,334,699.40        0.00
# 6823     6.20  мультфильм,комедия,приключения   147,606,826.51        0.00
#
#       refundable_support_mln  non_refundable_support_mln  box_office_mln
# 2053                    0.00                       23.00           10.23
# 2058                    0.00                       75.00          446.16
# 2472                   10.00                       70.00          196.57
# 2532                   20.00                        0.00           67.42
# 2615                   60.00                      100.00          184.49
# 2684                    0.00                       59.00            1.96
# 2788                    0.00                       35.00           72.94
# 2874                    0.00                        6.00           15.36
# 3047                   19.00                       51.00           70.30
# 3565                    0.00                      250.00        1,038.32
# 3675                   20.00                       20.00           55.11
# 3739                   25.00                       20.00           50.45
# 5673                   20.00                       40.00          225.20
# 5806                   10.00                       60.00          106.51
# 6008                   40.00                       40.00           83.37
# 6323                    0.00                      138.97            1.33
# 6823                   60.00                      120.00          147.61

# %%
len(data[(data.budget_mln==0)&((data.refundable_support_mln >0)|(data.non_refundable_support_mln>0))])
# Out:
# 17

# %%
round(17/len(data['budget_mln'])*100,2)
# Out:
# 0.23

# %% [markdown]
# Если вывести строки с некорректными значениями в столбце budget -общий бюджет фильма на экран, то видим, что они не являются неявными дубликатами, они составляют 0.23% от числа фильмов с государственной поддержкой.

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера ⚠️</b>
#
# Думаю, лучше проверить как-то иначе. Например, сгруппировать данные и посчитать количество фильмов с заданным названием или в этот код добавить цикл
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Количество фильмов с заданным названием было посчитано по срезу, их 17 и в срезе визуально видно, что фильмы не повторяются, поэтому проверку по каждому фильму убрала, действительно, это громоздко и в данном случае излишне.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Отлично!
# </div>

# %% [markdown]
# Решить вопрос с нулевыми значениями в столбце budget при наличии заполненной информации в столбце refundable_support или non_refundable_support, можно решить либо сложив значения столбцов refundable_support и non_refundable_support, либо удалив строки с нулевыми значениями. Учитывая, что данные в столбце budget не являются суммой значений столбцов refundable_support и non_refundable_support, и то, что они составляют только 0.2%, считаю правильным оставить только корректные существующие значения.

# %%
data.drop(data.index[data['budget_mln']==0],inplace=True)

# %%
data['budget_mln'].describe()
# Out:
# count     315.00
# mean      134.10
# std       191.23
# min        14.46
# 25%        46.15
# 50%        73.38
# 75%       150.00
# max     2,305.07
# Name: budget_mln, dtype: float64

# %% [markdown]
# Осталось 315 значений с которыми будем проводить дальнейшее исследование.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Здорово, что обратила внимание на эту ошибку с бюджетом
# </div>

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
data['year']=data['show_start_date'].dt.year

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['genres']=data['genres'].astype('str')
def genre_new(row, genre_index):
    array_genres=row['genres'].split(',')
    if len(array_genres)==0:
        return ''
    else:
        return array_genres[0]
    
data['genres_new']=data.apply(lambda row: genre_new(row,0),axis=1)

# %%
data['genres_new'].value_counts()
# Out:
# драма              1686
# nan                 956
# комедия             688
# боевик              616
# ужасы               573
# мультфильм          532
# триллер             520
# фантастика          408
# мелодрама           380
# фэнтези             358
# документальный      219
# аниме                74
# мюзикл               64
# детектив             56
# приключения          55
# военный              46
# криминал             39
# биография            33
# семейный             32
# детский              27
# история              26
# короткометражка      12
# концерт              10
# спорт                 9
# вестерн               7
# музыка                7
# для взрослых          3
# фильм-нуар            1
# реальное ТВ           1
# Name: genres_new, dtype: int64

# %%
sns.histplot(data['genres_new'], kde=False, bins=30)
plt.xlim(0,4)
plt.title('Жанры')
plt.xlabel('Жанры')
plt.xticks(rotation=45)
plt.ylabel('Частота')
plt.show()

# %%
data['director']=data['director'].astype('str')
def director_new(row, director_index):
    array_director=row['director'].split(',')
    if len(array_director)==0:
        return ''
    else:
        return array_director[0]
    
data['director_new']=data.apply(lambda row: director_new(row,0),axis=1)

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера ⚠️</b>
#
# Метод apply можно применить к признаку, а не датафрейму. Тогда в функцию попадет элемент строки, а не вся строка, и нам не придется писать две одинаковые функции
#
#     def new_func(elem):
#         try:
#             return elem.split(',')[0]
#         except:
#             return elem
#
#
#     data.director.apply(new_func)
# </div>

# %%
sns.histplot(data['director_new'], kde=False, bins=30)
plt.xlim(0,20)
plt.ylim(0,20)
plt.title('Директор')
plt.xlabel('Директор')
plt.xticks(rotation=90)
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
round((data['refundable_support_mln'].sum()+data['non_refundable_support_mln'].sum())/data['budget_mln'].sum(),2)
# Out:
# 0.45

# %% [markdown]
# Государственная поддержка составляет 45% от общего бюджета фильма.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# С добавлением признаков все хорошо
# </div>

# %% [markdown]
# ****Выводы:****
#
# **1.Cтудия-производитель:**
# *В данных столбца с названием студии-производителя - film_studio было пропущено 18 или 0.2% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности или необязательное поле для заполнения, а также мог иметь место технический сбой. Пропущенные значения с названием студии-производителя были удалены, так как невозможно восстановить корректные значения и количество пропущенных значений составляет 0.2%, их удаление не приведет к искажению результатов исследования.*
#
# **2.Cтрана-производитель:**
# *В данных столбца с названием страны-производителя - production_country было пропущено 1 или 0.0% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности, мог иметь место технический сбой. Пропущенные значения с названием страны-производителя были удалены, так как невозможно восстановить корректные значения и количество пропущенных значений составляет 0.0%, их удаление не приведет к искажению результатов исследования.*
#
# **3.Режиссёр:**
# *В данных столбца с именем режиссёра - director было пропущено 8 или 0.1% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности, возможно, необязательное поле для заполнения, а также мог иметь место технический сбой. Пропущенные значения с именем режиссёра были удалены, так как невозможно восстановить корректные значения и количество пропущенных значений составляет 0.1%, их удаление не приведет к искажению результатов исследования.*
#
# **4.Продюсер:**
# *В данных столбца с именем продюсера - producer было пропущено 564 или 7.6% значений. Можно предположить, что пропуски связаны с человеческим фактором -не заполнены по невнимательности, но, скорее всего, это необязательное поле для заполнения, а также мог иметь место технический сбой. Пропущенные значения с именем продюсера были заменены на значение 'unknown', так как невозможно восстановить корректные значения.*
#
# **5.Объем возвратных средств государственной поддержки:**
# *В данных столбца refundable_support -объём возвратных средств государственной поддержки было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку. Пропущенные значения объёмов возвратных средств государственной поддержки оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.*
#
# **6.Объем невозвратных средств государственной поддержки:**
# *В данных столбца nun_refundable_support -объём невозвратных средств государственной поддержки было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку. Пропущенные значения объёмов возвратных средств негосударственной поддержки оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.*
#
# **7.Общий бюджет фильма:**
# *В данных столбца budget -общий бюджет фильма было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку. Пропущенные значения общего бюджета фильма оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.*
#
# **8.Источник государственного финансирования:**
# *В данных столбца financing_source -источник государственного финансирования было пропущено 7127 или 95.5% значений. Можно предположить, что заполнены значения только для тех фильмов, которые получили государственную поддержку. Пропущенные значения источников государственного финансирования оставлены незаполненными. Дальнейшие исследования для фильмов, получившим государственную поддержку, будут производиться с имеющимися заполненными данными.*
#
# **9.Рейтинг фильма на КиноПоиске:**
# *В данных столбца ratings -рейтинг фильма на КиноПоиске было пропущено 948 или 12.7 % значений. Можно предположить, имел место человеческий фактор - не все данные заполнялись, либо данная информация была необязательна для заполнения, возможно, технический сбой. Часть заполненных данных отображалась некорректно. Пропущенные значения рейтинга фильма на КиноПоиске оставлены незаполненными, так как невозможно заменить корректными значениями.*
#
# **10.Жанр фильма:**
# *В данных столбца genres -жанр фильма было пропущено 957 или 12.8 % значений. Можно предположить, имел место человеческий фактор - не все данные заполнялись, либо данная информация была необязательна для заполнения, возможно, технический сбой. Пропущенные значения жанра фильма не заполнялись, так как нет возможности заполнить корректными значениями.*
#
# **11.Дата премьеры фильма:**
# *Методом datetime() превращаем в понятные для Python даты из типа object в тип datetime в столбце show_start_date -дата премьеры фильма.*
#
# **12.Название фильма:**
# *Всего 1270 строк, где в столбце title название фильма встречается более одного раза. В то же время во всех случаях номер прокатного удостоверения и дата премьеры фильма - это разные значения. Один фильм может иметь несколько прокатных удостоверений в случае, если они выдавались в разнае сроки и для разных прокатных целей. Также фильм мог поменять правообладателя или даже быть немного изменендля каких-либо творческих или коммерческих целей - с документальной точки зрения это требует выдачи новой "прокатки". Данные столбца оставляю без изменений.*
#
# **13.Тип фильма:**
# *В столбеце type - тип фильма, скорректированы проблемные значения.*
#
# **14.Номер прокатного удостоверения:**
# *Выявлено 2 повторяющиеся в столбце pu_number - номер прокатного удостоверения -221154310 и 221054410. При этом фильм с номером 221054410 - "Анализируй это!" и "Анализируй то!", скорее всего один и тот же фильм, который дважды внесен в базу данных по ошибке, так как основная информация дублируется -это неявный дубликат. Фильм с номером прокатного удостоверения 221154310 - "Как жениться и остаться холостым" и "Иоанна - женщина на папском престоле /По роман...", скорее всего два разных фильма, так как информация в названиии фильма, студии-производителе, директоре, режиссере, стране-производителе различается. Скорее всего здесь здесь допущена ошибка при внесении номера прокатного удостоверения или произошла техническая ошибка. Оба повторяющихся значения с номером прокатного удостоверения удаляю, так как номер прокатного удостоверения - это уникальные значения, которые не должны повторяться.*
#
# *В столбцах genres - жанр фильма, film_studio - студия-производитель, director - режиссёр, producer - продюсер, production_country - страна-производитель - многие параметры представлены списком, где через запятую перечислены несколько значений, что затрудняет их группировку и исследование. Поэтому созданы два новых столбца: с именем и фамилией главного режиссёра director_new и основным жанром фильма -genres_new. В столбцы вошли первые значения из списка режиссёров и жанров соответственно.*
#
# *Создан столбец с информацией о годе проката, в котором год выделен из даты премьеры фильма.*
#
# *Часть значений в столбце budget- общий бюджет фильма равен 0, хотя в стобцах refundable_support_mln - объём возвратных средств государственной поддержки и non_refundable_support_mln - объём невозвратных средств государственной поддержки есть значения - 17 значений или 0.23% от числа фильмов с государственной поддержкой, их удалили, т.к. нет возможности заменить на корректное значение. Для дальнейшего исследования осталось 315 значений.*
#
# *Посчитана, какую долю от общего бюджета фильма составляет государственная поддержка - 45%.*

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Здорово, что оставляешь промежуточные выводы
#
# </div>

# %% [markdown]
# <div class='alert alert-info'>
# <b>Комментарий студента</b>
#
# Добавила в выводы изменения по рейтингу и информацию по номеру прокатного удостоверения.
# </div>

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %% [markdown]
# Рассмотрим количество выходов фильмов в прокат по годам.

# %%
sns.histplot(data['year'], kde=False, bins=30)
plt.xlim(2009,2020)
plt.title('Прокат фильмов по годам')
plt.xlabel('Годы')
plt.xticks(rotation=45)
plt.ylabel('Частота')
plt.show()

# %%
data.groupby('year')['title'].count().sort_values(ascending=False).head(10)
# Out:
# year
# 2010    976
# 2019    925
# 2018    875
# 2016    814
# 2014    805
# 2015    699
# 2013    629
# 2011    620
# 2012    592
# 2017    503
# Name: title, dtype: int64

# %% [markdown]
#  Посчитаем долю, которую составляют фильмы с указанной информацией о прокате в кинотеатрах от общего числа фильмов.

# %%
round(data['box_office_mln'].count()/data['title'].count(),2)
# Out:
# 0.42

# %% [markdown]
# Больше всего фильмов было выпущено в прокат в 2010 году - 980, а в 2018-2019 годах, 926 и 879 фильмов соответственно. Меньше всего фильмов за анализируемый период было выпущено прокат в 2017 году - 505.
#
# Имеющаяся у нас информация о сборах от проката фильмов охватывает не все фильмы. Доля, которую составляют фильмы с указанием информации по сборам составляет 42% от общего числа фильмов.

# %%
data['title'].count()
# Out:
# 7438

# %%
year_box_office = pd.DataFrame()
year_box_office['sum_year_box_office'] = data.groupby('year')['box_office_mln'].sum()
year_box_office['count_year_box_office'] = data.groupby('year')['box_office_mln'].count()
year_box_office['percent_box_office'] = year_box_office['count_year_box_office'] / data['title'].count()
year_box_office['total_year']=data.groupby('year')['title'].count()
year_box_office['percent_year_total']=year_box_office['count_year_box_office']/year_box_office['total_year']
year_box_office.sort_values('percent_box_office', ascending = False)
# Out:
#       sum_year_box_office  count_year_box_office  percent_box_office  \
# year
# 2019            48,278.14                    529                0.07
# 2016            46,742.17                    522                0.07
# 2018            49,251.94                    470                0.06
# 2015            38,527.71                    459                0.06
# 2017            48,458.17                    355                0.05
# 2014             7,434.59                    278                0.04
# 2013                29.68                    184                0.02
# 2012                 6.86                    127                0.02
# 2011                14.04                    109                0.01
# 2010                 2.36                    105                0.01
#
#       total_year  percent_year_total
# year
# 2019         925                0.57
# 2016         814                0.64
# 2018         875                0.54
# 2015         699                0.66
# 2017         503                0.71
# 2014         805                0.35
# 2013         629                0.29
# 2012         592                0.21
# 2011         620                0.18
# 2010         976                0.11

# %% [markdown]
# Доля фильмов с указанием информации по сборам менялась в зависимости от года выпуска фильма в прокат.
#
# На 2010 - 2013 годы приходится наименьшее количество фильмов, по которым была предоставлена информация по сборам. Так, информация по сборам в 2010 году имеется только в 1% фильмов к общему количеству фильмов за весь рассматриваемый период (105 к 7438) или 11%  от 976 фильмов, вышедших в прокат в 2010 году. В 2011 году - 1% (109 к 7438) или 18% от 620 фильмов, вышедших в 2011 году.
#
# На 2015 - 2019 годы приходится наибольшее количество фильмов, по которым была предоставлена информация по сборам. В 2019 году имеется больше всего информации по сборам от проката - 7% фильмов к общему количеству фильмов за весь рааматриваемый период с 2010 по 2019 годы (529 к 7438) или 57% от 925 фильмам, вышедших в прока в 2019 году. В 2016 году 7% и 64% соответственно.
#
# 2019 год наболее всех остальных периодов предоставлен в данных.
#
# После острых нулевых, в начале десятых годов ситуация с российским кинопрокатом начинает стабилизироваться - произошли большие изменения к киноиндустрии -"пленка" уходит в прошлое, приходит "цифра", что дает возможность увеличить число копий фильмов, выпущенных в прокат, соответственно и рост сборов от проката в 2011 году. В 2013 году произошел первый прорыв по сборам - в прокате начали появляться первые фильмы-миллиардники. В 2012 году вступил в силу ФЗ "О защите детей от информации, причиняющей вред их здоровью и развитию", в частности, приведший к введению новой возрастной классификации, близкая к международной классификации (МРАА). В 2015 году Министерством культуры совместно с Фондом кино был запущен сервис, который позволяет получать информацию о показах фильмов, идущих в прокате в кинозалах - отсыда наиболее полная информация по сборам от проката за период 2015-2019 годы.

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера ❗</b>
#
# > Доля, которую составляют фильмы с указанием информации по сборам составляет 42% от общего числа фильмов.
#
# Проанализируй, как эта доля менялась по годам. Сделай вывод о том, какой период полнее всего представлен в данных.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента</b>
#
# Добавлена таблица по изменению доли по годам. Добавлен вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Хороший комментарий
#
# </div>

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
sns.relplot(x='year', y='box_office_mln', data=data)
total_area=np.linspace(0,300)
plt.title('Зависимость сборов от года выпуска в прокат')
plt.xlabel('Годы')
plt.ylabel('Сборы')
plt.show()

# %%
data.groupby('year')['box_office_mln'].sum().sort_values(ascending=False).head()
# Out:
# year
# 2018   49,251.94
# 2017   48,458.17
# 2019   48,278.14
# 2016   46,742.17
# 2015   38,527.71
# Name: box_office_mln, dtype: float64

# %% [markdown]
# Самые большие сборы от кинопроката наблюдаются в 2017-2019 годах. В 2018 - 49688.35, 2017 - 48563.73, 2019 - 48435.75.

# %%
data.groupby('year')['box_office_mln'].sum().sort_values().head()
# Out:
# year
# 2010       2.36
# 2012       6.86
# 2011      14.04
# 2013      29.68
# 2014   7,434.59
# Name: box_office_mln, dtype: float64

# %% [markdown]
# Наименьшее количество сборов от кинопроката в 2010 году - 2.36.
#
# Выведем описание значений столбца.

# %%
data['box_office_mln'].describe()
# Out:
# count   3,138.00
# mean       76.08
# std       240.35
# min         0.00
# 25%         0.08
# 50%         2.31
# 75%        23.46
# max     3,073.57
# Name: box_office_mln, dtype: float64

# %% [markdown]
# Обращает на себя внимание значение min = 0. Посмотрим на срез данных.

# %%
data[(data.box_office_mln==0)]
# Out:
#                                          title  pu_number  \
# 6                              Любовь и голуби  111007013
# 18                               Неподдающиеся  111003616
# 19                                  Неподсуден  111003716
# 22    Операция "Ы" и другие приключения Шурика  111007413
# 38                                   Мужики!..  111007213
# ...                                        ...        ...
# 5301                        Моя безумная семья  111010011
# 5343                      Хранитель времени 3D  121023411
# 5360              Резня /По пьесе Ясмины Резы/  121022511
# 5388                                  ВОИН.com  111004411
# 6804                   Счастье - это...Часть 2  111005319
#
#                show_start_date            type  \
# 6    2013-10-18 12:00:00+00:00  Художественный
# 18   2016-02-12 12:00:00+00:00  Художественный
# 19   2016-02-12 12:00:00+00:00  Художественный
# 22   2013-10-18 12:00:00+00:00  Художественный
# 38   2013-10-18 12:00:00+00:00  Художественный
# ...                        ...             ...
# 5301 2011-12-21 12:00:00+00:00  Художественный
# 5343 2011-12-15 12:00:00+00:00  Художественный
# 5360 2011-11-29 12:00:00+00:00  Художественный
# 5388 2011-07-04 12:00:00+00:00  Художественный
# 6804 2019-03-20 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 6                                 Киностудия "Мосфильм"
# 18                                Киностудия "Мосфильм"
# 19                                Киностудия "Мосфильм"
# 22                                Киностудия "Мосфильм"
# 38                                Киностудия "Мосфильм"
# ...                                                 ...
# 5301  ООО "Фокс Интернэшнл Продакшнс СНГ", НП "Интер...
# 5343                      ДжиКей Филмз, Инфинитум Найхл
# 5360  Эс Би Эс Продакшнз, Константин Филм, Эс Пи Ай ...
# 5388                        ООО "Культурные инициативы"
# 6804        ООО "Компания Парк Синема", ООО "ФильмФест"
#
#                production_country  \
# 6                            СССР
# 18                           СССР
# 19                           СССР
# 22                           СССР
# 38                           СССР
# ...                           ...
# 5301                       Россия
# 5343                          США
# 5360  Германия - Франция - Польша
# 5388                       Россия
# 6804                       Россия
#
#                                                director  \
# 6                                             В.Меньшов
# 18                                            Ю.Чулюкин
# 19                            В.Краснопольский, В.Усков
# 22                                             Л.Гайдай
# 38                                              И.Бабич
# ...                                                 ...
# 5301                                      Р.Давлетьяров
# 5343                                    Мартин Скорсезе
# 5360                                     Роман Полански
# 5388                                          Е.Бычкова
# 6804  А.Боровикова, Е.Войтович, З.Джиджилава, А.Тимо...
#
#                                                producer  \
# 6                                               unknown
# 18                                              unknown
# 19                                              unknown
# 22                                              unknown
# 38                                              unknown
# ...                                                 ...
# 5301                       Р.Давлетьяров, А.Котелевский
# 5343  Джонни Депп, Тим Хэдингтон, Грэм Кинг, Мартин ...
# 5360      Оливер Бербен, Мартин Московиц, Саид Бен Саид
# 5388                               В.Малышев, А.Малышев
# 6804                      ООО "Уолт Дисней Компани СНГ"
#
#                       age_restriction  refundable_support  ...  ratings  \
# 6     «12+» - для детей старше 12 лет                 NaN  ...     8.30
# 18      «6+» - для детей старше 6 лет                 NaN  ...     8.00
# 19      «6+» - для детей старше 6 лет                 NaN  ...     7.70
# 22      «6+» - для детей старше 6 лет                 NaN  ...     8.70
# 38      «6+» - для детей старше 6 лет                 NaN  ...     8.10
# ...                               ...                 ...  ...      ...
# 5301  «12+» - для детей старше 12 лет                 NaN  ...     5.60
# 5343  «12+» - для детей старше 12 лет                 NaN  ...     6.90
# 5360  «16+» - для детей старше 16 лет                 NaN  ...     7.40
# 5388  «12+» - для детей старше 12 лет                 NaN  ...     4.70
# 6804    «6+» - для детей старше 6 лет                 NaN  ...     6.00
#
#                           genres box_office  budget_mln  \
# 6              мелодрама,комедия   2,700.00         NaN
# 18             мелодрама,комедия     360.00         NaN
# 19                         драма     420.00         NaN
# 22    комедия,мелодрама,криминал     380.00         NaN
# 38                         драма   1,165.00         NaN
# ...                          ...        ...         ...
# 5301                     комедия   4,578.00         NaN
# 5343  драма,детектив,приключения     750.00         NaN
# 5360               драма,комедия   2,000.00         NaN
# 5388                     комедия     465.00         NaN
# 6804          семейный,мелодрама   4,398.40         NaN
#
#      refundable_support_mln  non_refundable_support_mln  box_office_mln  year  \
# 6                       NaN                         NaN            0.00  2013
# 18                      NaN                         NaN            0.00  2016
# 19                      NaN                         NaN            0.00  2016
# 22                      NaN                         NaN            0.00  2013
# 38                      NaN                         NaN            0.00  2013
# ...                     ...                         ...             ...   ...
# 5301                    NaN                         NaN            0.00  2011
# 5343                    NaN                         NaN            0.00  2011
# 5360                    NaN                         NaN            0.00  2011
# 5388                    NaN                         NaN            0.00  2011
# 6804                    NaN                         NaN            0.00  2019
#
#       genres_new      director_new
# 6      мелодрама         В.Меньшов
# 18     мелодрама         Ю.Чулюкин
# 19         драма  В.Краснопольский
# 22       комедия          Л.Гайдай
# 38         драма           И.Бабич
# ...          ...               ...
# 5301     комедия     Р.Давлетьяров
# 5343       драма   Мартин Скорсезе
# 5360       драма    Роман Полански
# 5388     комедия         Е.Бычкова
# 6804    семейный      А.Боровикова
#
# [455 rows x 23 columns]

# %%
len(data[(data.box_office_mln==0)])
# Out:
# 455

# %%
round(len(data[(data.box_office_mln==0)])/len(data['box_office_mln'])*100,2)
# Out:
# 6.12

# %%
data[(data.box_office_mln==0)]['box_office'].sum()
# Out:
# 646892.4

# %%
round(data[(data.box_office_mln==0)]['box_office'].sum()/data['box_office'].sum()*100,4)
# Out:
# 0.0003

# %% [markdown]
# В некоторых данных по сборам, приокруглении до млн.руб., составляют менее 1 млн. Таких значений 455 или 6.1% от количества, по которым есть информация и  сумма сборов по ним составляет 646892.4 руб. или менее 1% от общей суммы сборов.
#
# Посмотрим какие это значения.

# %%
data[(data.box_office_mln==0)]['box_office'].min()
# Out:
# 0.0

# %%
data[(data.box_office==0)]
# Out:
#                                                   title  pu_number  \
# 66                                         Анна Павлова  111011013
# 237                                            Подранки  111007613
# 596                                       Запах вереска  111003012
# 914     В тумане /По одноименной повести Василя Быкова/  121027712
# 932                                     Письмо для Момо  124002912
# 933                                        Летние войны  124002812
# 976                                        Гарегин Нжде  131000213
# 1126                                            Марафон  111006712
# 1387  Экзамен для двоих /По роману Джин Ханфф Корелитц/  121014613
# 1559  Последняя любовь мистера Моргана /По роману Фр...  121002614
# 1772                                  Весёлые ребята ;)  111002414
# 1782                          Анжелика, маркиза ангелов  121031913
# 1978                                    Люблю твою жену  121013014
# 2037                                 Кино про Алексеева  111007114
# 2078                 Курбан-роман. (История с жертвой).  111009614
# 2126                                   Поездка к матери  111002015
# 2219                       Прогулка по солнечному свету  121011614
# 2442                                   Звездный мальчик  111013915
# 2685                                    ПУСТЬ ТАК БУДЕТ  111009815
# 3595                                             Ананас  111017116
# 3827                               Москва, я люблю тебя  111001610
# 3994                              Стать Джоном Ленноном  121008610
# 4066                                            Дерево.  121020210
# 4790                    КРАСНЫЙ ЛЕД. Сага о хантах Югры  111005910
#
#                show_start_date            type  \
# 66   2013-12-19 12:00:00+00:00  Художественный
# 237  2013-10-18 12:00:00+00:00  Художественный
# 596  2012-05-23 12:00:00+00:00  Художественный
# 914  2012-11-07 12:00:00+00:00  Художественный
# 932  2012-10-25 12:00:00+00:00    Анимационный
# 933  2012-10-25 12:00:00+00:00    Анимационный
# 976  2013-04-23 12:00:00+00:00  Художественный
# 1126 2012-12-18 12:00:00+00:00  Художественный
# 1387 2013-06-11 12:00:00+00:00  Художественный
# 1559 2014-02-11 12:00:00+00:00  Художественный
# 1772 2014-02-27 12:00:00+00:00  Художественный
# 1782 2013-12-12 12:00:00+00:00  Художественный
# 1978 2014-06-23 12:00:00+00:00  Художественный
# 2037 2014-07-18 12:00:00+00:00  Художественный
# 2078 2014-09-02 12:00:00+00:00  Художественный
# 2126 2015-03-02 12:00:00+00:00  Художественный
# 2219 2014-06-11 12:00:00+00:00  Художественный
# 2442 2015-08-25 12:00:00+00:00  Художественный
# 2685 2015-06-01 12:00:00+00:00  Художественный
# 3595 2016-11-10 12:00:00+00:00  Художественный
# 3827 2010-02-09 12:00:00+00:00  Художественный
# 3994 2010-05-05 12:00:00+00:00  Художественный
# 4066 2010-11-03 12:00:00+00:00  Художественный
# 4790 2010-06-04 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 66    совместное производство Киностудия "Мосфильм",...
# 237                               Киностудия "Мосфильм"
# 596                                    ООО "Студия РИМ"
# 914   Ма Йа Де Фикшн, Лемминг Филм, Беларусьфильм, Д...
# 932   Кадокава Пикчерз, Продакшнз И Джи, Токио Броад...
# 933   Медхауз, Ниппон Телевижн Нетуорк Корпорейшн, К...
# 976      Эй Джи Кей Продакшнз, Пан Армениан Медиа Групп
# 1126                            ООО "Синема Арт Студио"
# 1387                                       Депф оф Филд
# 1559  Камински Штим Фильм, Бавариа Пикчерз, Сенатор ...
# 1772   ЗАО "ПРОДЮСЕРСКАЯ КОМПАНИЯ ВАЛЕРИЯ ТОДОРОВСКОГО"
# 1782                  Европа Корп., МонаФилм, ВилмаФилм
# 1978           Серендипити Пойнт Фильм, Номадик Пикчерз
# 2037                     ООО "Кинокомпания "Новые люди"
# 2078                                   ФОНД "ИННОВАЦИЯ"
# 2126                         ЗАО "Киностудия "М"-Фильм"
# 2219                         Вертиго Филмз, АйЭм Глобал
# 2442                              Киностудия "Мосфильм"
# 2685                ООО ПРОДЮСЕРСКАЯ КОМПАНИЯ "ДЕРЖАВА"
# 3595                            Рудак Владимир Иванович
# 3827  ООО "БФГ-МЕДИА-ПРОДАКШН", ООО "Продюсерская ко...
# 3994  Авер Медиа, Экосси Филмз, Филм 4, Норс Вест Ви...
# 4066  Ле Фильм Дю Позьон, Тэйлор Медиа, Скрин Ауастр...
# 4790  Департамент культуры и искусства ХМАО-Югры, ОО...
#
#                                      production_country  \
# 66                     СССР, Франция, Англия, Куба, ГДР
# 237                                                СССР
# 596                                              Россия
# 914   Германия - Нидерланды - Беларусь - Россия - Ла...
# 932                                              Япония
# 933                                              Япония
# 976                                             Армения
# 1126                                             Россия
# 1387                                                США
# 1559                  Германия - Бельгия - США -Франция
# 1772                                             Россия
# 1782                                            Франция
# 1978                                             Канада
# 2037                                             Россия
# 2078                                             Россия
# 2126                                             Россия
# 2219                                     Великобритания
# 2442                                               СССР
# 2685                                             Россия
# 3595                                             Россия
# 3827                                             Россия
# 3994                              Канада-Великобритания
# 4066                                  Франция-Австралия
# 4790                                             Россия
#
#                                                director  \
# 66                                         Эмиль Лотяну
# 237                                           Н.Губенко
# 596                                         А.Магомедов
# 914                                      Сергей Лозница
# 932                                      Окиура Хироюки
# 933                                       Мамору Хосода
# 976                                        Грач Кешишян
# 1126                                         К.Оганесян
# 1387                                           Пол Вайц
# 1559                                  Сандра Неттельбек
# 1772                                           А.Бобров
# 1782                                      Ариэль Зейтун
# 1978                                  Джеримайя С.Чечик
# 2037                                            М.Сегал
# 2078                                            С.Юзеев
# 2126                                 М.Косырев-Нестеров
# 2219                         Макс Джива, Дания Пасквини
# 2442                          Е.Зильберштейн, А.Дудоров
# 2685                                       О.Смольников
# 3595                                            В.Рудак
# 3827  Г.Михалков, Г.Натансон, В.Сторожева, А.Касатки...
# 3994                                     Сэм Тейлор Вуд
# 4066                                    Жюли Бертучелли
# 4790                                          О.Фесенко
#
#                                                producer  \
# 66                                              unknown
# 237                                             unknown
# 596                               М.Балашова, Е.Миронов
# 914                                        Хайно Декерт
# 932     Хироюки Икеда, Митсухиса Ишикава, Кацзуя Хамана
# 933   Такафуми Ватанабэ, Такуя Ито, Сэйдзи Окуда, Юи...
# 976                                        Грач Кешишян
# 1126                                         К.Оганесян
# 1387              Пол Вайц, Керри Кохански, Эндрю Миано
# 1559  Франк Камински, Астрид Камке, Филипп Кройцер, ...
# 1772                                      В.Тодоровский
# 1782        Эммануэль Жаклин, Павел Солк, Филипп Херинг
# 1978            Стефен Аликс, Эри Лантос, Роберт Лантош
# 2037                                        Н.Мокрицкая
# 2078                                         М.Галицкая
# 2126                                 М.Косырев-Нестеров
# 2219       Кэролайн Леви, Эллан Нибло, Джеймс Ричардсон
# 2442                                            unknown
# 2685  К.Лавров, Ю.Потапова, В.Бутер, С.Прудников, С....
# 3595                                 В.Рудак, А.Бабенко
# 3827                               Ю.Глоцер, Ю.Гинзбург
# 3994         Роберт Бернштейн, Кевин Лоудер, Дуглас Рэй
# 4066                                            unknown
# 4790                                           О.Урушев
#
#                              age_restriction  refundable_support  ...  \
# 66             «6+» - для детей старше 6 лет                 NaN  ...
# 237          «12+» - для детей старше 12 лет                 NaN  ...
# 596          «16+» - для детей старше 16 лет                 NaN  ...
# 914          «12+» - для детей старше 12 лет                 NaN  ...
# 932          «12+» - для детей старше 12 лет                 NaN  ...
# 933          «12+» - для детей старше 12 лет                 NaN  ...
# 976          «12+» - для детей старше 12 лет                 NaN  ...
# 1126         «16+» - для детей старше 16 лет                 NaN  ...
# 1387         «12+» - для детей старше 12 лет                 NaN  ...
# 1559         «16+» - для детей старше 16 лет                 NaN  ...
# 1772           «6+» - для детей старше 6 лет                 NaN  ...
# 1782         «16+» - для детей старше 16 лет                 NaN  ...
# 1978         «16+» - для детей старше 16 лет                 NaN  ...
# 2037         «12+» - для детей старше 12 лет                 NaN  ...
# 2078         «12+» - для детей старше 12 лет                 NaN  ...
# 2126         «16+» - для детей старше 16 лет                 NaN  ...
# 2219         «12+» - для детей старше 12 лет                 NaN  ...
# 2442  «0+» - для любой зрительской аудитории                 NaN  ...
# 2685         «12+» - для детей старше 12 лет                 NaN  ...
# 3595         «16+» - для детей старше 16 лет                 NaN  ...
# 3827         «16+» - для детей старше 16 лет                 NaN  ...
# 3994         «16+» - для детей старше 16 лет                 NaN  ...
# 4066         «16+» - для детей старше 16 лет                 NaN  ...
# 4790         «16+» - для детей старше 16 лет                 NaN  ...
#
#       ratings                       genres box_office  budget_mln  \
# 66       7.70       драма,биография,музыка       0.00         NaN
# 237      8.20                        драма       0.00         NaN
# 596      6.30                      комедия       0.00         NaN
# 914      6.50        драма,военный,история       0.00         NaN
# 932      7.40       аниме,мультфильм,драма       0.00         NaN
# 933      7.70  аниме,мультфильм,фантастика       0.00         NaN
# 976      7.90                    биография       0.00         NaN
# 1126     5.50            комедия,мелодрама       0.00         NaN
# 1387     5.80      мелодрама,комедия,драма       0.00         NaN
# 1559     6.90                        драма       0.00         NaN
# 1772      NaN                          nan       0.00         NaN
# 1782     8.00  драма,мелодрама,приключения       0.00         NaN
# 1978     6.00            мелодрама,комедия       0.00         NaN
# 2037     6.90                        драма       0.00         NaN
# 2078      NaN                          nan       0.00         NaN
# 2126     9.10               драма,семейный       0.00         NaN
# 2219     6.10       мюзикл,драма,мелодрама       0.00         NaN
# 2442     7.50                        драма       0.00         NaN
# 2685      NaN                          nan       0.00         NaN
# 3595     6.70      боевик,комедия,криминал       0.00         NaN
# 3827     4.50            мелодрама,комедия       0.00         NaN
# 3994     7.50    драма,мелодрама,биография       0.00         NaN
# 4066      NaN                          nan       0.00         NaN
# 4790     4.50                драма,история       0.00         NaN
#
#      refundable_support_mln  non_refundable_support_mln  box_office_mln  year  \
# 66                      NaN                         NaN            0.00  2013
# 237                     NaN                         NaN            0.00  2013
# 596                     NaN                         NaN            0.00  2012
# 914                     NaN                         NaN            0.00  2012
# 932                     NaN                         NaN            0.00  2012
# 933                     NaN                         NaN            0.00  2012
# 976                     NaN                         NaN            0.00  2013
# 1126                    NaN                         NaN            0.00  2012
# 1387                    NaN                         NaN            0.00  2013
# 1559                    NaN                         NaN            0.00  2014
# 1772                    NaN                         NaN            0.00  2014
# 1782                    NaN                         NaN            0.00  2013
# 1978                    NaN                         NaN            0.00  2014
# 2037                    NaN                         NaN            0.00  2014
# 2078                    NaN                         NaN            0.00  2014
# 2126                    NaN                         NaN            0.00  2015
# 2219                    NaN                         NaN            0.00  2014
# 2442                    NaN                         NaN            0.00  2015
# 2685                    NaN                         NaN            0.00  2015
# 3595                    NaN                         NaN            0.00  2016
# 3827                    NaN                         NaN            0.00  2010
# 3994                    NaN                         NaN            0.00  2010
# 4066                    NaN                         NaN            0.00  2010
# 4790                    NaN                         NaN            0.00  2010
#
#       genres_new        director_new
# 66         драма        Эмиль Лотяну
# 237        драма           Н.Губенко
# 596      комедия         А.Магомедов
# 914        драма      Сергей Лозница
# 932        аниме      Окиура Хироюки
# 933        аниме       Мамору Хосода
# 976    биография        Грач Кешишян
# 1126     комедия          К.Оганесян
# 1387   мелодрама            Пол Вайц
# 1559       драма   Сандра Неттельбек
# 1772         nan            А.Бобров
# 1782       драма       Ариэль Зейтун
# 1978   мелодрама   Джеримайя С.Чечик
# 2037       драма             М.Сегал
# 2078         nan             С.Юзеев
# 2126       драма  М.Косырев-Нестеров
# 2219      мюзикл          Макс Джива
# 2442       драма      Е.Зильберштейн
# 2685         nan        О.Смольников
# 3595      боевик             В.Рудак
# 3827   мелодрама          Г.Михалков
# 3994       драма      Сэм Тейлор Вуд
# 4066         nan     Жюли Бертучелли
# 4790       драма           О.Фесенко
#
# [24 rows x 23 columns]

# %%
data[(data.box_office_mln==0)]['box_office'].max()
# Out:
# 5000.0

# %% [markdown]
# В данных по сборам, округленных до 1 млн.руб., имеющим значение 0, минимальные сборы составляют 0, максимальные -5000 руб, т.е. нет искажения данных при округлении.

# %%
data.boxplot('box_office_mln')
plt.title('Диаграмма размаха')
plt.xlabel('Сборы')
# Out:
# Text(0.5, 0, 'Сборы')

# %%
data.groupby(['year'])['box_office_mln'].mean().plot(grid=True,figsize=(6,3),rot=45,ylim=0)
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# На графиках видим большие изменения сборов от проката в зависимости от года выхода фильма в прокат. В 2010-2013 - самые низкие сборы за весь рассматриваемый период. По всей видимости ощущались последствия экономического кризиса 2008 года. В 2014 году -другой кризис, уже внутри страны. С 2014 года наблюдается рост сборов от проката, который достиг пика в 2017 году.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Хорошо, что постаралась объяснить поведение цифр на графике
#
# </div>

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %%
data.groupby('year').agg({'box_office_mln': ['count','mean','median']})
data.pivot_table(columns='year',values='box_office_mln',aggfunc=('count','mean','median'))
# Out:
# year     2010   2011   2012   2013   2014   2015   2016   2017   2018   2019
# count  105.00 109.00 127.00 184.00 278.00 459.00 522.00 355.00 470.00 529.00
# mean     0.02   0.13   0.05   0.16  26.74  83.94  89.54 136.50 104.79  91.26
# median   0.00   0.00   0.01   0.00   0.02   4.78   3.78   9.92   8.82   4.60

# %% [markdown]
# Наиболее полно данными представлен период 2015 - 2019 г.
#
# В 2013 году произошел первый прорыв по сборам - в прокате начали появляться первые фильмы-миллиардники, с развитием киноиндустрии их количество росло, отсюда наблюдается большая разница между средним по сборам от проката и медианой.

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера ⚠️</b>
#
# Подскажи, с чем связана такая разница между средним и медианой?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента</b>
#
# Добавила.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Ты абсолютно права
#
# </div>

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %% [markdown]
# Рассмотрим параметр age_restriction -возрастная категория.

# %%
data['age_restriction'].unique()
# Out:
# array(['«18+» - запрещено для детей', '«6+» - для детей старше 6 лет',
#        '«12+» - для детей старше 12 лет',
#        '«16+» - для детей старше 16 лет',
#        '«0+» - для любой зрительской аудитории'], dtype=object)

# %% [markdown]
# Существует 5 групп, делящиеся по возрастным ограничениям аудитории - «18+» - запрещено для детей, «6+» - для детей старше 6 лет, «12+» - для детей старше 12 лет, «16+» - для детей старше 16 лет, «0+» - для любой зрительской аудитории'.

# %%
data['age_restriction'].value_counts()
# Out:
# «16+» - для детей старше 16 лет           2837
# «18+» - запрещено для детей               1600
# «12+» - для детей старше 12 лет           1581
# «0+» - для любой зрительской аудитории     803
# «6+» - для детей старше 6 лет              617
# Name: age_restriction, dtype: int64

# %% [markdown]
# Наибольшее количество фильмов относится к категории "16+" - 2848, наименьшее - к категории "6+" - 623.
#
# Нас интересует период с 2015 по 2019 годы. Для анализа создадим новый датафрейм, ограниченный данным временным периодом.

# %%
data_year=data[(data.year>=2015)]

# %%
data_year['age_restriction'].value_counts()
# Out:
# «16+» - для детей старше 16 лет           1164
# «18+» - запрещено для детей               1081
# «12+» - для детей старше 12 лет            779
# «6+» - для детей старше 6 лет              476
# «0+» - для любой зрительской аудитории     316
# Name: age_restriction, dtype: int64

# %% [markdown]
# В период с 2015-2019 наибольшее количество фильмов относится к категории "16+" - 1170, наименьшее - к категории "0+" - 316. Заметно значительное снижение фильмов для категории "0+", относительно фильмов других возрастных категорий.

# %%
age_pivot=data_year.pivot_table(index=['year','age_restriction'], values='box_office_mln',aggfunc=['count','median','mean', 'sum'])
age_pivot.columns=['count','median','mean', 'sum']
age_pivot.sort_values('sum',ascending=False).head(20)
# Out:
#                                       count  median   mean       sum
# year age_restriction
# 2017 «16+» - для детей старше 16 лет    120    9.64 155.79 18,694.57
# 2016 «16+» - для детей старше 16 лет    181    5.09  91.68 16,594.30
# 2018 «16+» - для детей старше 16 лет    155    8.75 105.02 16,278.42
#      «12+» - для детей старше 12 лет     66   10.04 216.17 14,267.27
# 2015 «12+» - для детей старше 12 лет     72   15.14 186.38 13,419.48
# 2019 «16+» - для детей старше 16 лет    178    3.21  71.65 12,753.42
#      «6+» - для детей старше 6 лет       80   12.53 158.81 12,704.95
#      «12+» - для детей старше 12 лет     85    3.41 149.18 12,680.19
# 2016 «6+» - для детей старше 6 лет       70    3.03 172.19 12,053.16
# 2017 «6+» - для детей старше 6 лет       44   50.28 273.43 12,031.04
# 2016 «12+» - для детей старше 12 лет     80    4.23 139.38 11,150.78
# 2015 «16+» - для детей старше 16 лет    165    4.32  65.34 10,781.57
# 2019 «18+» - запрещено для детей        183    5.60  55.31 10,121.83
# 2018 «6+» - для детей старше 6 лет       65   14.46 152.52  9,913.76
# 2017 «18+» - запрещено для детей        147    8.21  65.66  9,651.52
# 2018 «18+» - запрещено для детей        179    7.18  48.94  8,760.04
# 2015 «6+» - для детей старше 6 лет       52   19.52 163.79  8,517.28
# 2017 «12+» - для детей старше 12 лет     41    9.01 191.50  7,851.44
# 2016 «18+» - запрещено для детей        151    6.11  44.99  6,793.93
# 2015 «18+» - запрещено для детей        131    4.65  41.45  5,430.33

# %% [markdown]
# Наибольшие сборы в 2016-2019 годах собрали фильмы возрастной категории "16+" (2016 - 16664.60, 2017 - 18945.02, 2018 - 16503.62)

# %%
age_pivot=data_year.pivot_table(index=['year','age_restriction'], values='box_office_mln',aggfunc=['count','median','mean', 'sum'])
age_pivot.columns=['count','median','mean', 'sum']
age_pivot.sort_values('sum').head(10)
# Out:
#                                              count  median   mean      sum
# year age_restriction
# 2019 «0+» - для любой зрительской аудитории      3    3.89   5.92    17.75
# 2018 «0+» - для любой зрительской аудитории      5    3.62   6.49    32.45
# 2016 «0+» - для любой зрительской аудитории     40    2.68   3.75   150.00
# 2017 «0+» - для любой зрительской аудитории      3   22.18  76.53   229.60
# 2015 «0+» - для любой зрительской аудитории     39    2.94   9.72   379.05
#      «18+» - запрещено для детей               131    4.65  41.45 5,430.33
# 2016 «18+» - запрещено для детей               151    6.11  44.99 6,793.93
# 2017 «12+» - для детей старше 12 лет            41    9.01 191.50 7,851.44
# 2015 «6+» - для детей старше 6 лет              52   19.52 163.79 8,517.28
# 2018 «18+» - запрещено для детей               179    7.18  48.94 8,760.04

# %% [markdown]
# Наименьшее количество сборов у фильмов с возрастной категорией "0+". Во все исследуемые годы с 2015-2019 данная тенденция сохраняется. Скорее всего речь идет о мультфильмах и детских фильмах, идущих в утреннее и дневное время, билеты на которые продаются по более низким ценам.

# %%
age_pivot=data_year.pivot_table(index=['age_restriction','year'], values='box_office_mln',aggfunc=['count','median','mean', 'sum'])
age_pivot.columns=['count','median','mean', 'sum']
age_pivot.sort_values('count',ascending=False).head(20)
# Out:
#                                       count  median   mean       sum
# age_restriction                 year
# «18+» - запрещено для детей     2019    183    5.60  55.31 10,121.83
# «16+» - для детей старше 16 лет 2016    181    5.09  91.68 16,594.30
# «18+» - запрещено для детей     2018    179    7.18  48.94  8,760.04
# «16+» - для детей старше 16 лет 2019    178    3.21  71.65 12,753.42
#                                 2015    165    4.32  65.34 10,781.57
#                                 2018    155    8.75 105.02 16,278.42
# «18+» - запрещено для детей     2016    151    6.11  44.99  6,793.93
#                                 2017    147    8.21  65.66  9,651.52
#                                 2015    131    4.65  41.45  5,430.33
# «16+» - для детей старше 16 лет 2017    120    9.64 155.79 18,694.57
# «12+» - для детей старше 12 лет 2019     85    3.41 149.18 12,680.19
# «6+» - для детей старше 6 лет   2019     80   12.53 158.81 12,704.95
# «12+» - для детей старше 12 лет 2016     80    4.23 139.38 11,150.78
#                                 2015     72   15.14 186.38 13,419.48
# «6+» - для детей старше 6 лет   2016     70    3.03 172.19 12,053.16
# «12+» - для детей старше 12 лет 2018     66   10.04 216.17 14,267.27
# «6+» - для детей старше 6 лет   2018     65   14.46 152.52  9,913.76
#                                 2015     52   19.52 163.79  8,517.28
#                                 2017     44   50.28 273.43 12,031.04
# «12+» - для детей старше 12 лет 2017     41    9.01 191.50  7,851.44

# %%
age_pivot=data_year.pivot_table(index=['age_restriction','year'], values='box_office_mln',aggfunc=['count','median','mean', 'sum'])
age_pivot.columns=['count','median','mean', 'sum']
age_pivot.sort_values('count').head(20)
# Out:
#                                              count  median   mean       sum
# age_restriction                        year
# «0+» - для любой зрительской аудитории 2017      3   22.18  76.53    229.60
#                                        2019      3    3.89   5.92     17.75
#                                        2018      5    3.62   6.49     32.45
#                                        2015     39    2.94   9.72    379.05
#                                        2016     40    2.68   3.75    150.00
# «12+» - для детей старше 12 лет        2017     41    9.01 191.50  7,851.44
# «6+» - для детей старше 6 лет          2017     44   50.28 273.43 12,031.04
#                                        2015     52   19.52 163.79  8,517.28
#                                        2018     65   14.46 152.52  9,913.76
# «12+» - для детей старше 12 лет        2018     66   10.04 216.17 14,267.27
# «6+» - для детей старше 6 лет          2016     70    3.03 172.19 12,053.16
# «12+» - для детей старше 12 лет        2015     72   15.14 186.38 13,419.48
# «6+» - для детей старше 6 лет          2019     80   12.53 158.81 12,704.95
# «12+» - для детей старше 12 лет        2016     80    4.23 139.38 11,150.78
#                                        2019     85    3.41 149.18 12,680.19
# «16+» - для детей старше 16 лет        2017    120    9.64 155.79 18,694.57
# «18+» - запрещено для детей            2015    131    4.65  41.45  5,430.33
#                                        2017    147    8.21  65.66  9,651.52
#                                        2016    151    6.11  44.99  6,793.93
# «16+» - для детей старше 16 лет        2018    155    8.75 105.02 16,278.42

# %% [markdown]
# Количество фильмов, выпускаемых в прокат для категории "0+" в период 2017-2019 г значительно снизилось (2015-39, 2016-40, 2017-3, 2018-5, 2019-3.

# %% [markdown]
# Наибольшее количество фильмов, выпускаемых в прокат - для категорий "16+" и "18+".

# %%
for aggfunc in ['sum','count','median']: 
    ax=(
        data_year
        .pivot_table(index='year',columns='age_restriction',values='box_office_mln',aggfunc=aggfunc)
        .plot(title=aggfunc)
    )
    ax.legend(bbox_to_anchor=(1, 1.05))
    plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
# <b> Комментарий от ревьюера ⚠️</b>
#
# Ты вроде посчитала все, что можно, но у нас в итоге получилась куча таблиц и графиков, в которых сложно разобраться.
#
# Если к тебе придет менеджер и попросит ответить на вопрос про зависимость сборов от категории, то ему нужен будет простой и короткий ответ. Тут лучше всего построить линейный график с динамикой в разрезе категорий по годам. Например так
#
#     for aggfunc in ['sum','count','median']:
#         ax=(
#             data_year
#             .pivot_table(index='year',columns='age_restriction',values='box_office_mln',aggfunc=aggfunc)
#             .plot(title=aggfunc)
#         )
#         ax.legend(bbox_to_anchor=(1, 1.05))
#         plt.show()
#
# По этим графикам кажется можно сделать все твои выводы, но они занимают меньше места. Кстати, тут видно, что большие суммарные сборы 16+ связаны скорее с количеством фильмов. А в среднем успешнее фильмы в категориях 6+ и 0+ (по медиане).
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента</b>
#
# Спасибо! Очень информативный график, я его вставила, а свои убрала, у меня не получилось объединить...Две таблицы тоже убрала, т.к. они практически дублировали друг друга. По категории 6+ и 0+ полностью согласна, я о них думала, но в моей "красоте" это было не очевидно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# 👍
#
# </div>

# %% [markdown]
# ****Выводы:****
#
# **Проведен исследовательский анализ данных:**
#
# **1.Количество фильмов, выходящих в прокат по годам:**
# *Наибольшее количество фильмов вышло в прокат в 2010 году - 980, 2019 - 926, 2018 - 879, 2016 - 817, 2014 - 806, 2015 - 705, 2013 - 629, 2011 - 620, 2012 - 592 и 2017 - 505. Больше всего фильмов было выпущено в прокат в 2010 году - 980, а в 2018-2019 годах, 926 и 879 фильмов соответственно. Меньше всего фильмов за анализируемый период было выпущено прокат в 2017 году - 505.
# Имеющаяся у нас информация о сборах от проката фильмов охватывает не все фильмы. Доля, которую составляют фильмы с указанием информации по сборам составляет 42% от общего числа фильмов. *
#
# *Доля фильмов с указанием информации по сборам менялась в зависимости от года выпуска фильма в прокат.На 2010 - 2013 годы приходится наименьшее количество фильмов, по которым была предоставлена информация по сборам. Так, информация по сборам в 2010 году имеется только в 1% фильмов к общему количеству фильмов за весь рассматриваемый период (105 к 7438) или 11% от 976 фильмов, вышедших в прокат в 2010 году. В 2011 году - 1% (109 к 7438) или 18% от 620 фильмов, вышедших в 2011 году.*
#
# *На 2015 - 2019 годы приходится наибольшее количество фильмов, по которым была предоставлена информация по сборам. В 2019 году имеется больше всего информации по сборам от проката - 7% фильмов к общему количеству фильмов за весь рааматриваемый период с 2010 по 2019 годы (529 к 7438) или 57% от 925 фильмам, вышедших в прока в 2019 году. В 2016 году 7% и 64% соответственно.2019 год наболее всех остальных периодов предоставлен в данных.*
#
# *В начале десятых годов произошли большие изменения к киноиндустрии -"пленка" уходит в прошлое, приходит "цифра", что дает возможность увеличить число копий фильмов, выпущенных в прокат, соответственно и рост сборов от проката в 2011 году. В 2013 году произошел первый прорыв по сборам - в прокате начали появляться первые фильмы-миллиардники. В 2012 году вступил в силу ФЗ "О защите детей от информации, причиняющей вред их здоровью и развитию", в частности, приведший к введению новой возрастной классификации, близкая к международной классификации (МРАА). В 2015 году Министерством культуры совместно с Фондом кино был запущен сервис, который позволяет получать информацию о показах фильмов, идущих в прокате в кинозалах - отсыда наиболее полная информация по сборам от проката за период 2015-2019 годы.*
#
# **2.Сумма сборов в зависимости от динамики проката по годам:**
# *Самые большие сборы от кинопроката наблюдаются в 2017-2019 годах. В 2018 - 49688.35, 2017 - 48563.73, 2019 - 48435.75. Наименьшее количество сборов от кинопроката в 2010 году - 2.36. В некоторых данных по сборам, приокруглении до млн.руб., составляют менее 1 млн. Таких значений 455 или 6.1% от количества, по которым есть информация и сумма сборов по ним составляет 646892.4 руб. или менее 1% от общей суммы сборов. Наблюдаются большие изменения сборов от проката в зависимости от года выхода фильма в прокат. В 2010-2013 - самые низкие сборы за весь рассматриваемый период. По всей видимости ощущались последствия экономического кризиса 2008 года. В 2014 году -другой кризис, уже внутри страны. С 2014 года наблюдается рост сборов от проката, который достиг пика в 2017 году. Наиболее полно данными представлен период 2015 - 2019 г.*
#
#
#
#
# **3.Влияние возрастных ограничений аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год:**
# *Наибольшее количество фильмов относится к категории "16+" - 2848, наименьшее - к категории "6+" - 623. В период с 2015-2019 наибольшее количество фильмов относится к категории "16+" - 1170, наименьшее - к категории "0+" - 316. Заметно значительное снижение фильмов для категории "0+", относительно фильмов других возрастных категорий. Наибольшие сборы в 2016-2019 годах собрали фильмы возрастной категории "16+" (2016 - 16664.60, 2017 - 18945.02, 2018 - 16503.62). Наименьшее количество сборов у фильмов с возрастной категорией "0+". Во все исследуемые годы с 2015-2019 данная тенденция сохраняется. Скорее всего речь идет о мультфильмах и детских фильмах, идущих в утреннее и дневное время, билеты на которые продаются по более низким ценам. Количество фильмов, выпускаемых в прокат для категории "0+" в период 2017-2019 г значительно снизилось (2015-39, 2016-40, 2017-3, 2018-5, 2019-3. Наибольшее количество фильмов, выпускаемых в прокат - для категорий "16+" и "18+". В среднем успешнее фильмы в категориях 6+ и 0+ (по медиане)*

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента</b>
#
# Добавила комментарий по изменению доли по годам.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Хорошо, что обновляешь выводы
#
# </div>

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %%
data['support_total']=data['refundable_support_mln']+data['non_refundable_support_mln']

# %%
data['support_ratio']=round(data['support_total']/data['budget_mln'],2)

# %%
data['budget_payback']=round(data['box_office_mln']/data['budget_mln'],2)

# %%
data['support_payback']=round(data['box_office_mln']/data['support_total'],2)

# %% [markdown]
# Исследуем датафрейм, в который включает в себя данные только по фильмам, которые получили государственную поддержку.

# %%
data_bud=data[(data.budget_mln>0)&((data.refundable_support_mln >0)|(data.non_refundable_support_mln>0))]

# %% [markdown]
# Посмотрим какие типы фильмов получили государственную поддержку.

# %%
budget_pivot=data_bud.pivot_table(index='type', values=['budget_mln','refundable_support_mln', 'non_refundable_support_mln',
                                                        'box_office_mln','ratings'],aggfunc=('sum', 'mean','count'))
budget_pivot.head()
# Out:
#                box_office_mln                  budget_mln                   \
#                         count   mean       sum      count   mean       sum
# type
# Анимационный               24 210.20  5,044.89         25 209.62  5,240.46
# Документальный              0    NaN      0.00          1  33.00     33.00
# Художественный            277 123.81 34,295.32        289 127.91 36,966.78
#
#                non_refundable_support_mln                 ratings       \
#                                     count  mean       sum   count mean
# type
# Анимационный                           25 46.46  1,161.52      25 5.85
# Документальный                          1  3.00      3.00       1 8.00
# Художественный                        289 48.41 13,989.19     274 6.05
#
#                         refundable_support_mln
#                     sum                  count  mean      sum
# type
# Анимационный     146.30                     25 29.60   740.00
# Документальный     8.00                      1  0.00     0.00
# Художественный 1,656.70                    289 10.09 2,915.00

# %% [markdown]
# Государственную поддержку за исследуемый период получили:
#
# -289 художественных фильма в размере 16904.19 (13989.19 из которых составляют невозвратные средства государственной поддержки - non_refundable_support_mln и 2915.0 -возвратные средства государственной поддержки - refundable_support_mln) или 45.7% от  budget_mln - общего бюджета художественных фильмов 36966.78;
# -25 анимационных фильмов в размере 1901.52 (1161.52 -невозвратные средства, 740.0 - возвратные) -36.2% от общего бюджета анимационных фильмов 5240.46;
#
# -1 документальный фильм в размере 3.0 (3.0 -невозвратные средства, 0 -возвратные) -9% от бюджета документального фильма 33.0.
#
# Сборы составили:
#
# -34295.32 от показа художественных фильмов, что составляет 92.8% к общему бюджету художественных фильмов 36966.78;
# -5044.89 от показа анимационных фильмов или 96.3% к общему бюджету анимационных фильмов 5240.46;
# -сборы от показа документального фильма - 0 при общем бюджете фильма 33.0.

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Весь текст слился в один абзац, посмотри [тут](https://paulradzkov.com/2014/markdown_cheatsheet/) про синтаксис Markdown
#
# </div>

# %%
round(data_bud['box_office_mln'].sum()/data_bud['budget_mln'].sum(),2)
# Out:
# 0.93

# %% [markdown]
# Средняя окупаемость фильмов составляет 93% от общего бюджета фильмов.

# %%
round(data_bud['box_office_mln'].sum()/(data_bud['support_total'].sum()),2)
# Out:
# 2.09

# %% [markdown]
# Окупаемость средств государственной поддержки составляет 209%.

# %%
budget_pivot=data_bud.pivot_table(index='year', values=['support_ratio','support_total', 'budget_payback',
                                                        'support_payback', 'budget_mln','ratings'],aggfunc=('mean','count'))
budget_pivot.head(10)
# Out:
#      budget_mln        budget_payback      ratings      support_payback       \
#           count   mean          count mean   count mean           count mean
# year
# 2013          2 127.72              2 0.06       2 6.70               2 0.10
# 2014         15  85.30             15 0.63      14 5.96              15 1.64
# 2015         80  91.37             79 0.48      77 6.14              79 1.27
# 2016         58 124.64             57 0.60      54 5.69              57 1.21
# 2017         39 178.77             37 1.02      37 6.05              37 3.16
# 2018         52 127.92             52 1.13      50 6.04              52 2.43
# 2019         69 181.78             59 0.88      66 6.18              59 2.15
#
#      support_ratio      support_total
#              count mean         count  mean
# year
# 2013             2 0.47             2 67.17
# 2014            15 0.52            15 36.60
# 2015            80 0.53            80 40.34
# 2016            58 0.55            58 68.57
# 2017            39 0.48            39 79.46
# 2018            52 0.51            52 59.58
# 2019            69 0.50            69 68.46

# %% [markdown]
# По годам доля государственной поддержки к общему бюджету фильмов находится примерно на одном уровне - 47-55%. Окупаемость от общего бюджета фильмов менялась по годам -наблюдается рост в 2014-2016 относительно 2013 года, наибольшего пика достигнув в 2017-2018 годах, со снижением в 2019 году. Фильмы с датой премьеры в 2019 году, особенно, если премьера пришлась на конец года, основную часть сборов скорее всего могут получить в 2020 году, по которому у нас нет информации. Кроме того, в 2020 году началась пандемия короновируса, что привело к закрытию и ограничению работы кинотеатров и снижению сборов. По окупаемости средств государственной поддержки динамика по годам схожа с динамикой окупаемости общего бюджета.

# %%
payback=['budget_payback', 'support_payback', 'support_ratio']
data_bud.groupby(['year'])[payback].mean().plot(grid=True,figsize=(9,3),rot=90,ylim=0)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data_bud.groupby('genres_new')['budget_payback'].mean().sort_values(ascending=False).head()
# Out:
# genres_new
# спорт        2.41
# комедия      1.53
# биография    1.14
# ужасы        1.05
# мультфильм   1.00
# Name: budget_payback, dtype: float64

# %%
data_bud.groupby('genres_new')['budget_payback'].mean().sort_values().head()
# Out:
# genres_new
# детский     0.02
# мелодрама   0.04
# детектив    0.07
# мюзикл      0.16
# триллер     0.26
# Name: budget_payback, dtype: float64

# %% [markdown]
# По отношению сборов к общему бюджету фильма, наиболее окупаемыми являются фильмы жанров спорт, комедия. Наименее окупаемые -детские фильмы и мелодрамы.

# %%
data_bud.groupby('genres_new')['ratings'].mean().sort_values(ascending=False).head(10)
# Out:
# genres_new
# криминал     7.50
# детский      7.12
# спорт        6.93
# биография    6.90
# детектив     6.76
# мюзикл       6.55
# военный      6.47
# драма        6.42
# боевик       6.34
# фантастика   6.20
# Name: ratings, dtype: float64

# %%
data_bud.groupby('genres_new')['ratings'].mean().sort_values().head(10)
# Out:
# genres_new
# ужасы         5.20
# история       5.35
# семейный      5.41
# комедия       5.52
# реальное ТВ   5.60
# триллер       5.70
# приключения   5.87
# мелодрама     5.91
# мультфильм    5.91
# фэнтези       6.09
# Name: ratings, dtype: float64

# %% [markdown]
# Наиболее высокие рейтинги у фильмов, относящихся к жанру криминал -7.5, детские фильмы-7.12. Самые низкие рейтинги у фильмов ужасов - 5.2 и исторических фильмов -5.35. У детских фильмов высокий рейтинг, но низкая окупаемость. Скорее всего, это связано стем, что детские фильмы показывают в основном на утренних и дневных сеансах, на которые устанавливаются более низкие цены на билеты и посещают сеансы дети с родителями.

# %%
budget_pivot=data_bud.pivot_table(index='genres_new', values=['support_ratio','support_total', 'budget_payback',
                                                        'support_payback', 'budget_mln','ratings'],aggfunc=('mean','count','median'))
budget_pivot.head(10)
# Out:
#            budget_mln               budget_payback             ratings       \
#                 count   mean median          count mean median   count mean
# genres_new
# nan                15  62.86  46.92             14 0.73   0.01       0  NaN
# биография           3 176.31 131.00              3 1.14   0.32       3 6.90
# боевик              5 120.69 150.00              5 0.59   0.33       5 6.34
# военный             9 142.88 109.81              9 0.86   0.19       9 6.47
# детектив            5 239.64 130.00              5 0.07   0.06       5 6.76
# детский             4  45.97  46.94              3 0.02   0.03       4 7.12
# драма              92 120.13  58.27             86 0.41   0.06      92 6.42
# история             4 536.26 499.92              4 0.56   0.51       4 5.35
# комедия            68  86.99  72.17             67 1.53   0.31      68 5.52
# криминал            3 142.20  59.94              3 0.32   0.23       3 7.50
#
#                   support_payback             support_ratio              \
#            median           count mean median         count mean median
# genres_new
# nan           NaN              14 1.28   0.03            15 0.62   0.65
# биография    6.90               3 5.52   1.90             3 0.35   0.21
# боевик       6.30               5 2.26   1.13             5 0.44   0.41
# военный      6.40               9 2.75   0.50             9 0.41   0.35
# детектив     6.80               5 0.32   0.15             5 0.49   0.56
# детский      7.25               3 0.03   0.04             4 0.65   0.67
# драма        6.40              86 0.96   0.12            92 0.54   0.62
# история      5.90               4 1.10   1.25             4 0.43   0.39
# комедия      5.75              67 3.46   0.71            68 0.53   0.56
# криминал     7.80               3 0.49   0.36             3 0.66   0.66
#
#            support_total
#                    count   mean median
# genres_new
# nan                   15  36.67  30.00
# биография              3  37.50  27.51
# боевик                 5  50.80  35.00
# военный                9  46.89  45.00
# детектив               5  97.00  55.00
# детский                4  29.75  29.50
# драма                 92  56.95  30.00
# история                4 255.00 240.00
# комедия               68  43.87  32.50
# криминал               3  93.33  40.00

# %%
for aggfunc in ['mean','median']: 
    ax=(
        data_bud
        .pivot_table(index='genres_new',values=['support_payback','ratings'],aggfunc=aggfunc)
        .plot(title=aggfunc,kind='bar', figsize=(15,3))
    )
    ax.legend(bbox_to_anchor=(0.5, 1.05))
    plt.show()

# %% [markdown]
# К наиболее успешным жанрам, если рассматривать сборы от проката фильмов к объему государственной поддержки этих фильмов, относятся к жанрам биография, приключения, спорт, комедия. Наименее успешные относительно окупаемости средств государственной поддержки- детские фильмы, мелодрамы, драмы.

# %%
for aggfunc in ['mean','median']: 
    ax=(
        data_bud
        .pivot_table(index='genres_new',values=['budget_payback','support_payback'],aggfunc=aggfunc)
        .plot(title=aggfunc,kind='bar', figsize=(15,3))
    )
    ax.legend(bbox_to_anchor=(1, 1.55))
    plt.show()

# %% [markdown]
# Наиболее окупаемые спортивные фильмы, приключения, семейные фильмы.

# %%
genres_sup = pd.DataFrame()
genres_sup['genr_ratings_mean'] = data_bud.groupby('genres_new')['ratings'].mean()
genres_sup['genr_box_office'] = data_bud.groupby('genres_new')['box_office_mln'].mean()
genres_sup['support_genr_count'] = data_bud.groupby('genres_new')['support_total'].count()
genres_sup['support_genr_mean'] = data_bud.groupby('genres_new')['support_total'].mean()                                                                                                                                             
genres_sup['genr_bud_payback_count']= data_bud.groupby('genres_new')['budget_payback'].count()
genres_sup['genr_bud_payback_mean']= data_bud.groupby('genres_new')['budget_payback'].mean()
genres_sup['genr_bud_payback_median']= data_bud.groupby('genres_new')['budget_payback'].median()
genres_sup['total_genres']=data.groupby('genres_new')['title'].count()

genres_sup.sort_values('genr_bud_payback_median', ascending = False)
# Out:
#              genr_ratings_mean  genr_box_office  support_genr_count  \
# genres_new
# спорт                     6.93           989.26                   3
# семейный                  5.41            97.40                   7
# ужасы                     5.20            71.01                  10
# приключения               5.87           200.93                   7
# мультфильм                5.91           201.80                  26
# история                   5.35           363.87                   4
# реальное ТВ               5.60            32.72                   1
# боевик                    6.34            79.87                   5
# биография                 6.90           172.29                   3
# комедия                   5.52           182.11                  68
# фантастика                6.20            75.54                  10
# фэнтези                   6.09            90.53                  11
# криминал                  7.50            79.93                   3
# военный                   6.47           113.07                   9
# мюзикл                    6.55            25.43                   4
# детектив                  6.76            27.71                   5
# драма                     6.42           105.17                  92
# триллер                   5.70            33.95                  14
# детский                   7.12             1.01                   4
# мелодрама                 5.91             3.43                  14
# nan                        NaN           105.74                  15
#
#              support_genr_mean  genr_bud_payback_count  genr_bud_payback_mean  \
# genres_new
# спорт                   151.67                       3                   2.41
# семейный                 48.43                       6                   0.75
# ужасы                    35.50                      10                   1.05
# приключения              99.43                       6                   0.58
# мультфильм               74.29                      25                   1.00
# история                 255.00                       4                   0.56
# реальное ТВ              53.00                       1                   0.41
# боевик                   50.80                       5                   0.59
# биография                37.50                       3                   1.14
# комедия                  43.87                      67                   1.53
# фантастика              115.60                       9                   0.39
# фэнтези                  93.90                      11                   0.43
# криминал                 93.33                       3                   0.32
# военный                  46.89                       9                   0.86
# мюзикл                   60.11                       4                   0.16
# детектив                 97.00                       5                   0.07
# драма                    56.95                      86                   0.41
# триллер                  50.69                      14                   0.26
# детский                  29.75                       3                   0.02
# мелодрама                26.79                      13                   0.04
# nan                      36.67                      14                   0.73
#
#              genr_bud_payback_median  total_genres
# genres_new
# спорт                           1.87             9
# семейный                        0.76            32
# ужасы                           0.71           573
# приключения                     0.68            55
# мультфильм                      0.52           532
# история                         0.51            26
# реальное ТВ                     0.41             1
# боевик                          0.33           616
# биография                       0.32            33
# комедия                         0.31           688
# фантастика                      0.30           408
# фэнтези                         0.27           358
# криминал                        0.23            39
# военный                         0.19            46
# мюзикл                          0.13            64
# детектив                        0.06            56
# драма                           0.06          1686
# триллер                         0.06           520
# детский                         0.03            27
# мелодрама                       0.02           380
# nan                             0.01           956

# %%
data_bud[(data_bud.budget_payback>=2)&(data_bud.genres_new=='спорт')]
# Out:
#                title  pu_number           show_start_date            type  \
# 5653  Движение вверх  111011817 2017-12-21 12:00:00+00:00  Художественный
#
#                                 film_studio production_country      director  \
# 5653  ООО "Студия "ТРИТЭ" Никиты Михалкова"             Россия  А.Мегердичев
#
#                                                producer  \
# 5653  Л.Верещагин, А.Златопольский, Н.Михалков, ООО ...
#
#                     age_restriction  refundable_support  ...  \
# 5653  «6+» - для детей старше 6 лет                0.00  ...
#
#       refundable_support_mln  non_refundable_support_mln box_office_mln  year  \
# 5653                    0.00                      400.00       2,779.69  2017
#
#      genres_new  director_new  support_total  support_ratio  budget_payback  \
# 5653      спорт  А.Мегердичев         400.00           0.68            4.71
#
#       support_payback
# 5653             6.95
#
# [1 rows x 27 columns]

# %% [markdown]
# Есть случаи, когда медианные значения окупаемости значительно отличаются от средних значений в жанрах спорт, комедия и пр. Выведя срез по жанру спорт, мы видим фильм-миллиардник "Движение вверх", который оказал влияние на такой разброс средних и медианных значений.

# %% [markdown]
# <div class="alert alert-danger">
#
# <b> Комментарий от ревьюера ❗</b>
#
# Подскажи, на что мы тут смотрим, если у большей части жанров нет подписей по оси Х?
#
# И лучше использовать другой тип графика, потому что линейный график обычно показывает динамику. Можно попробовать построить столбчатую диаграмму.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента</b>
#
# Поменяла графики, на мой взгляд стало более понятно. Спасибо за подсказку по типу графика.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Замечательно! Графики, действительно, стали понятнее.
#
# </div>

# %% [markdown]
# ***Выводы:***
#
# **Проведено исследование фильмов, которые получили государственную поддержку:**
#
# *Государственную поддержку за исследуемый период получили: -289 художественных фильма в размере 16904.19 (13989.19 из которых составляют невозвратные средства государственной поддержки - non_refundable_support_mln и 2915.0 -возвратные средства государственной поддержки - refundable_support_mln) или 45.7% от budget_mln - общего бюджета художественных фильмов 36966.78; -25 анимационных фильмов в размере 1901.52 (1161.52 -невозвратные средства, 740.0 - возвратные) -36.2% от общего бюджета анимационных фильмов 5240.46; -1 документальный фильм в размере 3.0 (3.0 -невозвратные средства, 0 -возвратные) -9% от бюджета документального фильма 33.0. Сборы составили: -34295.32 от показа художественных фильмов, что составляет 92.8% к общему бюджету художественных фильмов 36966.78; -5044.89 от показа анимационных фильмов или 96.3% к общему бюджету анимационных фильмов 5240.46; -сборы от показа документального фильма - 0 при общем бюджете фильма 33.0.*
#
# *Средняя окупаемость фильмов составляет 93% от общего бюджета фильмов.*
#
# *По годам доля государственной поддержки к общему бюджету фильмов находится примерно на одном уровне - 47-55%. Окупаемость от общего бюджета фильмов менялась по годам -наблюдается рост в 2014-2016 относительно 2013 года, наибольшего пика достигнув в 2017-2018 годах, со снижением в 2019 году. Фильмы с датой премьеры в 2019 году, особенно, если премьера пришлась на конец года, основную часть сборов скорее всего могут получить в 2020 году, по которому у нас нет информации. Кроме того, в 2020 году началась пандемия короновируса, что привело к закрытию и ограничению работы кинотеатров и снижению сборов. По окупаемости средств государственной поддержки динамика по годам схожа с динамикой окупаемости общего бюджета.*
#
# *По отношению сборов к общему бюджету фильма, наиболее окупаемыми являются фильмы жанров спорт, комедия. Наименее окупаемы детские фильмы и мелодрамы.*

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# у тебя получилось интересное исследование! Думаю, еще тут можно попробовать посмотреть на средние рейтинги фильмов с гос.поддержкой и без нее в разрезе жанров, изучить основные источники финансирования или что-то в этом духе.
#
# </div>

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# **При анализе рынка российского кинопроката выявлены следующие тенденции:**
#
# **Количество фильмов, выходящих в прокат по годам: Наибольшее количество фильмов вышло в прокат в 2010 году - 980, 2019 - 926, 2018 - 879, 2016 - 817, 2014 - 806, 2015 - 705, 2013 - 629, 2011 - 620, 2012 - 592 и 2017 - 505. Больше всего фильмов было выпущено в прокат в 2010 году - 980, а в 2018-2019 годах, 926 и 879 фильмов соответственно. Меньше всего фильмов за анализируемый период было выпущено прокат в 2017 году - 505. Имеющаяся у нас информация о сборах от проката фильмов охватывает не все фильмы. Доля, которую составляют фильмы с указанием информации по сборам составляет 42% от общего числа фильмов.**
#
# **Сумма сборов в зависимости от динамики проката по годам: Самые большие сборы от кинопроката наблюдаются в 2017-2019 годах. В 2018 - 49688.35, 2017 - 48563.73, 2019 - 48435.75. Наименьшее количество сборов от кинопроката в 2010 году - 2.36. В некоторых данных по сборам, приокруглении до млн.руб., составляют менее 1 млн. Таких значений 455 или 6.1% от количества, по которым есть информация и сумма сборов по ним составляет 646892.4 руб. или менее 1% от общей суммы сборов. Наблюдаются большие изменения сборов от проката в зависимости от года выхода фильма в прокат. В 2010-2013 - самые низкие сборы за весь рассматриваемый период. По всей видимости ощущались последствия экономического кризиса 2008 года. В 2014 году -другой кризис, уже внутри страны. С 2014 года наблюдается рост сборов от проката, который достиг пика в 2017 году. Наиболее полно данными представлен период 2015 - 2019 г.**
#
# **Влияние возрастных ограничений аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год: Наибольшее количество фильмов относится к категории "16+" - 2848, наименьшее - к категории "6+" - 623. В период с 2015-2019 наибольшее количество фильмов относится к категории "16+" - 1170, наименьшее - к категории "0+" - 316. Заметно значительное снижение фильмов для категории "0+", относительно фильмов других возрастных категорий. Наибольшие сборы в 2016-2019 годах собрали фильмы возрастной категории "16+" (2016 - 16664.60, 2017 - 18945.02, 2018 - 16503.62). Наименьшее количество сборов у фильмов с возрастной категорией "0+". Во все исследуемые годы с 2015-2019 данная тенденция сохраняется. Скорее всего речь идет о мультфильмах и детских фильмах, идущих в утреннее и дневное время, билеты на которые продаются по более низким ценам. Количество фильмов, выпускаемых в прокат для категории "0+" в период 2017-2019 г значительно снизилось (2015-39, 2016-40, 2017-3, 2018-5, 2019-3. Наибольшее количество фильмов, выпускаемых в прокат - для категорий "16+" и "18+".**
#
# **Влияние государственной поддержки: Государственную поддержку за исследуемый период получили: -289 художественных фильма в размере 16904.19 (13989.19 из которых составляют невозвратные средства государственной поддержки - non_refundable_support_mln и 2915.0 -возвратные средства государственной поддержки - refundable_support_mln) или 45.7% от budget_mln - общего бюджета художественных фильмов 36966.78; -25 анимационных фильмов в размере 1901.52 (1161.52 -невозвратные средства, 740.0 - возвратные) -36.2% от общего бюджета анимационных фильмов 5240.46; -1 документальный фильм в размере 3.0 (3.0 -невозвратные средства, 0 -возвратные) -9% от бюджета документального фильма 33.0. Сборы составили: -34295.32 от показа художественных фильмов, что составляет 92.8% к общему бюджету художественных фильмов 36966.78; -5044.89 от показа анимационных фильмов или 96.3% к общему бюджету анимационных фильмов 5240.46; -сборы от показа документального фильма - 0 при общем бюджете фильма 33.0.Средняя окупаемость фильмов составляет 93% от общего бюджета фильмов. По годам доля государственной поддержки к общему бюджету фильмов находится примерно на одном уровне - 47-55%. Окупаемость от общего бюджета фильмов менялась по годам -наблюдается рост в 2014-2016 относительно 2013 года, наибольшего пика достигнув в 2017-2018 годах, со снижением в 2019 году. Фильмы с датой премьеры в 2019 году, особенно, если премьера пришлась на конец года, основную часть сборов скорее всего могут получить в 2020 году, по которому у нас нет информации. Кроме того, в 2020 году началась пандемия короновируса, что привело к закрытию и ограничению работы кинотеатров и снижению сборов. По окупаемости средств государственной поддержки динамика по годам схожа с динамикой окупаемости общего бюджета. По отношению сборов к общему бюджету фильма, наиболее окупаемыми являются фильмы жанров спорт, комедия. Наименее окупаемы детские фильмы и мелодрамы.**

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Хороший вывод
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <b> Комментарий от ревьюера ✔️</b>
#
# Спасибо за твою работу! Ты хорошо справилась с подготовкой и анализом данных.
#
# Осталось немного дополнить проект:
#
# - поправить обработку пропусков
# - проверить дубликаты
# - изучить долю фильмов в прокате
# - прокомментировать график в "Исследуйте фильмы, которые получили государственную поддержку"
#
# Задавай вопросы к моим комментариям, если есть. Жду твои исправления :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2 ✔️</b>
#
# Спасибо, что учла мои комментарии. Надеюсь, эта работа была полезна для тебя. Я принимаю проект и желаю удачи в прохождении курса!
#
# </div>
